# %%
import requests

url = 'https://notes.ayushsharma.in/technology'

data = requests.get(url)

print(data.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#
#
#
#
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
# 	<title>Ayush Sharma ☕ + 🎧 + 🕹️ - Technology</title>
# 	<meta name="description" content="Technology - Musings on Technology. Mostly tutorials and rants, some lunacy." />
#
# 	<link rel="canonical" href="https://www.ayush.nz/technology">
#
# 	<!-- RSS -->
# 	<link rel="alternate" type="application/rss+xml"
# 		title="Ayush Sharma ☕ + 🎧 + 🕹️"
# 		href="https://www.ayush.nz/feed-everything.xml">
#
# 	<!-- Favicons -->
# 	<link rel="apple-touch-icon" sizes="180x180"
# 		href="https://www.ayush.nz/static/images/meta/favicon/apple-touch-icon.png">
# 	<link rel="icon" type="image/png" sizes="32x32"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon-32x32.png">
# 	<link rel="icon" type="image/png" sizes="16x16"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon-16x16.png">
# 	<link rel="manifest"
# 		href="https://www.ayush.nz/static/images/meta/favicon/site.webmanifest">
# 	<link rel="mask-icon"
# 		href="https://www.ayush.nz/static/images/meta/favicon/safari-pinned-tab.svg"
# 		color="#5bbad5">
# 	<link rel="shortcut icon"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon.ico">
# 	<meta name="msapplication-TileColor" content="#da532c">
# 	<meta name="msapplication-config"
# 		content="https://www.ayush.nz/static/images/meta/favicon/browserconfig.xml">
# 	<meta name="theme-color" content="#ffffff">
#
# 	<meta name="apple-mobile-web-app-title" content="Technology
# 		- Ayush Sharma ☕ + 🎧 + 🕹️">
# 	<meta name="application-name" content="Technology
# 		- Ayush Sharma ☕ + 🎧 + 🕹️">
#
# 	<!-- Fonts -->
# 	<link href="https://fonts.googleapis.com/css2?family=Fira+Code:wght@400;700&family=Roboto:wght@400;700&display=swap"
# 		rel="stylesheet">
#
# 	<!-- CSS -->
# 	<link rel="stylesheet" href="https://www.ayush.nz/css/main.css">
# 	<link rel="preconnect" href="https://fonts.googleapis.com">
# 	<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# 	<link href="https://fonts.googleapis.com/css2?family=Tinos&family=Fugaz+One&display=swap" rel="stylesheet">
#
# 	<!-- OG tags -->
# 	<meta property="og:site_name" content="Ayush Sharma ☕ + 🎧 + 🕹️" />
# 	<meta property=“og:title” content=“Technology - Ayush Sharma ☕ + 🎧 + 🕹️" />
# 	<meta property="og:description"
# 		content="Technology - Musings on Technology. Mostly tutorials and rants, some lunacy." />
# 	<meta property="og:url"
# 		content="https://www.ayush.nz/technology" />
# 	<meta property="og:type" content="website" />
#
#
# </head>
#
# <body>
#
#   <div class="container">
# 	<nav class="navbar fixed-top navbar-expand-lg">
# 		<div class="container-fluid">
#
# 			<a class="navbar-brand" href="/" title="Ayush Sharma ☕ + 🎧 + 🕹️">
# 				ayush<span class="d-sm-none">'s</span><span class="d-none d-sm-inline"> sharma's</span> notes<span
# 					class="d-none d-sm-inline mx-1"><span class="mx-1" title="tea">☕</span>+<span class="mx-1"
# 						title="music">🎧</span>+<span class="mx-1" title="video games">🕹️</span></span>
# 			</a>
#
# 			<button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav"
# 				aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
# 				<span class="navbar-toggler-icon"></span>
# 			</button>
#
# 			<div class="collapse navbar-collapse" id="navbarNav">
#
# 				<ul class="navbar-nav ms-auto">
#
#
#
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link  " href="/"
# 						title="Home" ><i class="fas fa-home mx-1"></i>Home</a>
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link  " href="/life-stuff"
# 						title="☕ Life stuff" >☕ Life stuff</a>
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link  active" href="/technology"
# 						title="🎧 Technology" aria-current=\>🎧 Technology</a>
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link  " href="/video-games"
# 						title="🕹️ Video Games" >🕹️ Video Games</a>
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link  " href="/meta"
# 						title="🛠️ META" >🛠️ META</a>
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link  " href="/about"
# 						title="About Me" ><i class="fas fa-laugh-beam mx-1"></i>About Me</a>
#
#
# 					<!-- For META -->
#
#
# 					<!-- For blog posts -->
#
#
#
#
# 					<a class="nav-link text-warning " href="#subscribe"
# 						title="Subscribe!" ><i class="fas fa-rss-square mx-1"></i>Subscribe!</a>
#
# 				</ul>
# 			</div>
# 		</div>
# 	</nav>
# </div>
#
#   <div class="nav-spacer">&nbsp;</div>
#
#   <div class="container">
#     <div class="row row-cols-1">
#
#     <h1><span class="me-2">🎧</span>Technology</h1>
#     <div class="h-caption">Musings on Technology. Mostly tutorials and rants, some lunacy.</div>
# </div>
# <div class="row row-cols-1 row-cols-md-3 g-3 mt-0">
#
#
#     <div class="col">
#         <a href="/2022/11/consuming-apis-responsibly" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2022-11-21-consuming-apis-responsibly.png"
#             width="100%" height="310" alt="Card image for Consuming APIs responsibly" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Consuming APIs responsibly</h5>
#             <small class="card-text text-muted">Or: Etiquette and table manners for pinging other people's servers.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Nov 2022</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2022/02/creating-article-series-posts-navigation-jekyll" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2022-02-18-creating-article-series-posts-navigation-jekyll-series-navigation.png"
#             width="100%" height="310" alt="Card image for Create a series of posts with navigation in Jekyll" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Create a series of posts with navigation in Jekyll</h5>
#             <small class="card-text text-muted">Add Jekyll posts into a series with series navigation.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Feb 2022</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2022/01/practical-light-dark-mode-jekyll-bootstrap5" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2022-01-25-practical-light-dark-mode-jekyll-bootstrap5-banner.jpg"
#             width="100%" height="310" alt="Card image for A practical guide to light and dark mode in Bootstrap 5 and Jekyll" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">A practical guide to light and dark mode in Bootstrap 5 and Jekyll</h5>
#             <small class="card-text text-muted">Implementing light and dark mode on your Bootstrap 5 + Jekyll website.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jan 2022</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2022/01/nemo-file-manager-ubuntu-20.04-linux-nautilus-alternative" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2022-01-25-nemo-file-manager-ubuntu-20.04-linux-nautilus-alternative-home.jpg"
#             width="100%" height="310" alt="Card image for Nemo - The Ubuntu file manager you didn’t know you needed" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Nemo - The Ubuntu file manager you didn’t know you needed</h5>
#             <small class="card-text text-muted">Celebrate 2022 with a shiny new file manager for Ubuntu!</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jan 2022</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2022/01/announcing-fediverse-to" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2022-01-01-announcing-fediverse-to.png"
#             width="100%" height="310" alt="Card image for Announcing Fediverse.to!" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Announcing Fediverse.to!</h5>
#             <small class="card-text text-muted">I've been working on a search engine for Fediverse instances!</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jan 2022</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/11/easy-pretty-url-redirects-with-jekyll-and-netlify" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-11-16-easy-pretty-url-redirects-with-jekyll-and-netlify.jpg"
#             width="100%" height="310" alt="Card image for Easy pretty URL redirects with Jekyll and Netlify" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Easy pretty URL redirects with Jekyll and Netlify</h5>
#             <small class="card-text text-muted">Combine Jekyll and Netlify to create pretty URL redirects as easy as 1-2-3.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Nov 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/11/linking-jekyll-pages-back-to-their-git-source-code" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-11-16-linking-jekyll-pages-back-to-their-git-source-code.jpg"
#             width="100%" height="310" alt="Card image for Linking Jekyll pages back to their Git source code" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Linking Jekyll pages back to their Git source code</h5>
#             <small class="card-text text-muted">Add a link back to the public Git hosting link for any static Jekyll blog.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Nov 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/11/optimising-jpg-and-png-images-for-a-jekyll-blog" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-11-16-optimising-jpg-and-png-images-for-a-jekyll-blog.jpg"
#             width="100%" height="310" alt="Card image for Optimising JPG and PNG images for a Jekyll website" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Optimising JPG and PNG images for a Jekyll website</h5>
#             <small class="card-text text-muted">Use CLI tools to generate resized and optimised thumbnails for articles header images.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Nov 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/11/using-lunr-js-to-create-client-side-website-search-index" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-11-01-using-lunr-js-to-create-client-side-website-search-index-banner.svg"
#             width="100%" height="310" alt="Card image for Quick and easy client-side JavaScript search with Lunr.js" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Quick and easy client-side JavaScript search with Lunr.js</h5>
#             <small class="card-text text-muted">Display search results from any JSON data object in the browser using Lunr.js.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Nov 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/10/creating-light-and-dark-themes-for-websites-correctly-using-prefers-color-scheme" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-10-10-creating-light-and-dark-themes-for-websites-correctly-using-prefers-color-scheme.gif"
#             width="100%" height="310" alt="Card image for Creating light and dark themes for websites the right way using prefers-color-scheme" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Creating light and dark themes for websites the right way using prefers-color-scheme</h5>
#             <small class="card-text text-muted">Blur the line between desktop and web by letting the OS style your website or webapp.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Oct 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/10/make-linux-apps-for-notion-mastodon-webapps-using-nativefier" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-10-10-make-linux-apps-for-notion-mastodon-webapps-using-nativefier-banner.png"
#             width="100%" height="310" alt="Card image for Make Linux apps for Notion, Mastodon, or any web app using Nativefier" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Make Linux apps for Notion, Mastodon, or any web app using Nativefier</h5>
#             <small class="card-text text-muted">Notion is an awesome life manager. And Mastodon is great for decentralised internet shenanigans. With Nativefier, I can now enjoy them as apps on Ubuntu 20.04.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Oct 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/10/inserting-dynamic-data-into-jekyll-static-sites-using-python-or-bash" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Inserting dynamic data into Jekyll static sites using Python or Bash</h5>
#             <small class="card-text text-muted">Auto-generate Jekyll configuration files with content and avoid creating an API backend.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Oct 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/introduction-to-ansible" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Introduction to Ansible</h5>
#             <small class="card-text text-muted">Ansible is the answer to custom scripts and tooling that eventually snowball into a kludge which breaks more things than it fixes.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/introduction-to-yaml" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Introduction to YAML</h5>
#             <small class="card-text text-muted">What is YAML and why is it about time we started using it?</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/introduction-to-jekyll" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2016-08-15-introduction-to-jekyll-new-article.png"
#             width="100%" height="310" alt="Card image for Introduction to Jekyll" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Introduction to Jekyll</h5>
#             <small class="card-text text-muted">Jekyll is a framework for building websites - write your content in Markdown, use HTML/CSS for structure and presentation, and Jekyll compiles it all into static HTML. No servers. No backends. No fuss.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/multi-machine-setup-and-configuration-with-vagrant" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Multi-machine Setup and Configuration with Vagrant</h5>
#             <small class="card-text text-muted">If you ever need to test an app and a database, did you know you can use Vagrant to bring up multiple testing machines at once? Here's how.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/provisioning-with-vagrant" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Provisioning with Vagrant</h5>
#             <small class="card-text text-muted">Ansible works well to provision a Vagrant box with everything installed from the get-go.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/introduction-to-vagrant" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Introduction to Vagrant</h5>
#             <small class="card-text text-muted">Vagrant helps you run other operating systems on your computer, meaning you can build things, test things, and do crazy shit without blowing up your own system.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/a-guide-to-web-scraping-in-python-using-beautifulsoup" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">A Guide to Web Scraping in Python using BeautifulSoup</h5>
#             <small class="card-text text-muted">Web-scraping is a useful but often neglected technical skill. The BeautifulSoup library in Python makes extracting HTML from web pages easy. Do with that what you will ;)</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/08/using-variables-in-jekyll-to-define-custom-content" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Using variables in Jekyll to define custom content</h5>
#             <small class="card-text text-muted">I recently discovered that Jekyll's config.yml can be used to define custom variables for reusing content. I feel like I've been living under a rock all this time. But to err over and over again is human.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/07/the-evolution-of-ayushsharma-in" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-07-15-the-evolution-of-ayushsharma-in-many-devices.png"
#             width="100%" height="310" alt="Card image for The evolution of ayushsharma.in: Jekyll, Bootstrap, Netlify, static websites, and responsive design." />
#
#
#         <div class="card-body">
#             <h5 class="card-title">The evolution of ayushsharma.in: Jekyll, Bootstrap, Netlify, static websites, and responsive design.</h5>
#             <small class="card-text text-muted">In this article, I'll highlight some ideas for Jekyll collections, blog category pages, responsive web-design, and netlify.toml to make static website maintenance a breeze.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/07/5-key-best-practices-for-sane-and-usable-terraform-setups" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">5 key best practices for sane and usable Terraform setups</h5>
#             <small class="card-text text-muted">These are the top 5 lessons I've learned after 5 years of Terraform-ing.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/07/cloud-infrastructure-sast-terraform-checkov" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-07-13-cloud-infrastructure-sast-terraform-checkov.svg"
#             width="100%" height="310" alt="Card image for Cloud Infrastructure SAST: Scanning Terraform for security vulnerabilities and non-compliance using Checkov" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Cloud Infrastructure SAST: Scanning Terraform for security vulnerabilities and non-compliance using Checkov</h5>
#             <small class="card-text text-muted">In this article I explore Checkov, a static code analysis tool for Terraform.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/07/terraform-plus-helm-a-match-made-in-heaven-hell" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2021-07-12-terraform-plus-helm-a-match-made-in-heaven-hell-choices.svg"
#             width="100%" height="310" alt="Card image for Terraform + Helm: A match made in heaven/hell?" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Terraform + Helm: A match made in heaven/hell?</h5>
#             <small class="card-text text-muted">I've just discovered that Terraform can deploy Helm Charts as well. But I'm not sure if I like it.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/07/automating-argocd-using-argocd" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/automating-argocd-with-argocd-deployment.png"
#             width="100%" height="310" alt="Card image for Automating ArgoCD using ArgoCD!" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Automating ArgoCD using ArgoCD!</h5>
#             <small class="card-text text-muted">In this tutorial, I will show you how to automatically create multiple Applications in ArgoCD using ArgoCD!</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2021/07/getting-started-with-argocd" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/getting-started-with-argocd-successful-nginx-deployment.png"
#             width="100%" height="310" alt="Card image for Getting started with ArgoCD" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Getting started with ArgoCD</h5>
#             <small class="card-text text-muted">In this post we meet ArgoCD: a simple pull-based GitOps deployment tool which syncs K8s manifest files with a cluster for easy and no-nonsense deployments.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2021</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/09/creating-ready-to-use-aws-security-groups-using-terraform-registry-named-groups-and-named-rules" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2020-09-11-creating-ready-to-eat-aws-security-groups-using-terraform-registry-named-groups-and-named-rules.png"
#             width="100%" height="310" alt="Card image for Creating ready-to-use AWS Security Groups using Terraform Registry, Named Groups, and Named Rules" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Creating ready-to-use AWS Security Groups using Terraform Registry, Named Groups, and Named Rules</h5>
#             <small class="card-text text-muted">Create parameterized AWS security groups quickly and consistently with Terraform Registry.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/09/creating-aws-vpcs-in-2-minutes-with-terraform-registry" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Creating AWS VPCs in 2 minutes with Terraform Registry</h5>
#             <small class="card-text text-muted">Create parameterized AWS VPCs quickly and consistently with Terraform Registry.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/06/continuous-delivery-on-gitlab-pushing-docker-images-to-dockerhub-using-gitlab-pipelines" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Continuous delivery on GitLab: Pushing Docker images to DockerHub using GitLab Pipelines</h5>
#             <small class="card-text text-muted">Build and push Docker images to DockerHub using GitLab's Pipelines feature.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jun 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/06/configuring-elasticsearch-snapshots-using-slm-on-google-compute-engine" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Configuring Elasticsearch snapshots using SLM on Google Compute Engine</h5>
#             <small class="card-text text-muted">A tutorial on how to configure automatic snapshots of Elasticsearch using the in-built Snapshot Lifecycle Manager on Google Compute Engine.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jun 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/06/working-from-home-and-software-engineering" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">​​Working From Home and Software Engineering</h5>
#             <small class="card-text text-muted">Your time and attention is your primary resource, so deploy it wisely.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jun 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/04/the-virus-and-the-cloud-tips-on-aws-cost-saving" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">​​The Virus ​😷​ and the Cloud ​⛅​: Tips on AWS cost-saving in these weird ​🤯​ times</h5>
#             <small class="card-text text-muted">2020 is the year startups are trying to save aggresively on cloud spend. I list down some key learnings based on my experience.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Apr 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/03/replicating-bitbucket-pipelines-on-your-laptop-for-local-debugging" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Replicating Bitbucket Pipelines on your laptop for local debugging</h5>
#             <small class="card-text text-muted">I love Bitbucket Pipelines, and debugging them on your laptop is even easier thanks to Docker containers. I'll show you how to debug Serverless deployments and diagnose broken builds.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Mar 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/02/cloning-another-bitbucket-repo-in-bitbucket-pipelines" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Cloning another Bitbucket repository in Bitbucket Pipelines</h5>
#             <small class="card-text text-muted">I'll show you how to allow one Bitbucket repo to clone another during a Pipeline build.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Feb 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2020/02/deploying-git-submodules-in-bitbucket-pipelines" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Deploying git submodules in Bitbucket Pipelines</h5>
#             <small class="card-text text-muted">Git submodules makes it easy have repos for common dependencies, but how to actually clone them in your Bitbucket Pipeline?</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Feb 2020</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/08/automating-ecr-container-builds-using-bitbucket-pipelines" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/2019-08-30-automating-ecr-container-builds-using-bitbucket-pipelines-ecr-overview.png"
#             width="100%" height="310" alt="Card image for Automating Amazon Elastic Container (ECR) container builds using Bitbucket Pipelines" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Automating Amazon Elastic Container (ECR) container builds using Bitbucket Pipelines</h5>
#             <small class="card-text text-muted">I'll show you how to build a Docker image in a Pipeline and push it to a container registry, in this case Amazon ECR.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/08/taming-aws-costs-with-cost-and-usage-reports-and-aws-athena" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Taming AWS costs with Cost and Usage Reports + AWS Athena</h5>
#             <small class="card-text text-muted">AWS Cost & Usage Reports with AWS Athena are vital for understanding cloud spend. I'll show you some handy Athena queries to break things down.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/06/exporting-bitucket-repos-pipelines-python" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Exporting Bitucket repositories and Pipelines with Python</h5>
#             <small class="card-text text-muted">Bitbucket doesn't offer a dashboard yet, or an easy way to fetch information for all your repos and Pipelines. So I wrote a handy Python script for the job. It's great for configuring alerts or building near-real-time dashboards!</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jun 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/06/rediscovering-logo-with-bob-the-turtle" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/rediscovering-logo-python-turtle-sierpinski-triangle.jpg"
#             width="100%" height="310" alt="Card image for Rediscovering Logo with Bob the turtle" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Rediscovering Logo with Bob the turtle</h5>
#             <small class="card-text text-muted">My very first programming language was Logo! I can still remember guiding that fuzzy little on-screen turtle to draw simple and complex shapes. So I found the Logo Python module and took a walk down memory lane.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jun 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/05/automating-serverless-framework-deployments-using-bitbucket-pipelines" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/bitbucket-pipelines-serverless-framework.png"
#             width="100%" height="310" alt="Card image for Automating Serverless framework deployments using Bitbucket Pipelines" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Automating Serverless framework deployments using Bitbucket Pipelines</h5>
#             <small class="card-text text-muted">The open-source Serverless framework makes it easy to build and deploy Lambda stacks. I'll walk you through deploying Serverless apps automatically using Pipelines.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">May 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/05/automating-aws-lambda-deployments-using-bitbucket-pipelines-bitbucket-pipes" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Automating AWS Lambda deployments using Bitbucket Pipelines and Bitbucket Pipes</h5>
#             <small class="card-text text-muted">Pipes is another great Continuous Delivery feature in Bitbucket: pre-built, ready-to-use, and parameterized deployment jobs.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">May 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/03/algorithms-in-python-exchange-sorts" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Algorithms in Python: Exchange Sorts</h5>
#             <small class="card-text text-muted">Notes on implementing the basic Exchange sort algorithms in Python.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Mar 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2019/01/the-three-ways-of-devops-notes-on-the-phoenix-project" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">The Three Ways of DevOps: Notes on The Phoenix Project</h5>
#             <small class="card-text text-muted">The Phoenix Project is one of the most approachable books for DevOps available today. Highly recommended, especially if you don't already know Conway's Law.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jan 2019</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/10/working-with-numpy-in-python" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Working with NumPy in Python</h5>
#             <small class="card-text text-muted">My Udacity Python Nanodegree introduced using NumPy to handle large arrays and datasets in Python. I put some notes togther for referencing later.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Oct 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/09/data-types-in-python" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Data Types in Python</h5>
#             <small class="card-text text-muted">Some quick notes describing the basic data types in Python3 and their features.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/09/dockerizing-tweet-toot-a-practical-guide-to-deploying-your-app-using-docker" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Dockerizing Tweet-Toot: A practical guide to deploying your app using Docker</h5>
#             <small class="card-text text-muted">Tweet-Toot is my personal project, a Twitter relay for the Mastodon social network. I recently dockerized the setup and put these notes together to explain the process.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/09/sublime-text-3-setup-for-jekyll-development" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">SublimeText 3 setup for Jekyll development</h5>
#             <small class="card-text text-muted">SublimeText has some cool plugins for setting up a basic Jekyll development environment. Take a look.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/09/gartners-magic-quadrants-a-summary-of-cloud-infrastructure-as-a-service-providers-over-the-last-5-years" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/gartner-magic-quadrant-for-cloud-infrastructure-as-a-service-worldwide-2018.png"
#             width="100%" height="310" alt="Card image for Gartner's Magic Quadrants: A summary of cloud Infrastructure-as-a-Service providers over the last 5 years" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Gartner's Magic Quadrants: A summary of cloud Infrastructure-as-a-Service providers over the last 5 years</h5>
#             <small class="card-text text-muted">Gartner's Magic Quadrants was one of the the first industry reports I read which covered where the cloud vendor's were headed and what their strengths and weaknesses were. I took some time to consolidate the Gartner findings over the last 5 years for comparison.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/09/tweet-toot-building-a-bot-for-mastodon-using-python" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Tweet-Toot: Building a bot for Mastodon using Python</h5>
#             <small class="card-text text-muted">I joined the Mastodon social network in 2016 and felt a need for building a Twitter relay. We all left the birdsite for many reasons but not the people we met. So this project is a way to bring some of them over to Mastodon, in practice if not in spirit.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/07/moving-from-cloudflare-to-stackpath" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/cloudflare-stackpath-notes.ayushsharma.in-stackpath_ttfb.png"
#             width="100%" height="310" alt="Card image for Moving from CloudFlare to StackPath" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Moving from CloudFlare to StackPath</h5>
#             <small class="card-text text-muted">I love Cloudflare, but after facing some issues with TTFB I decided to move to StackPath, which proved to be a lot faster and feature-rich.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/07/understanding-vendor-lock-in-and-breaking-the-cycle" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Understanding vendor lock-in and breaking the cycle</h5>
#             <small class="card-text text-muted">I went through one of Gartner's reports, and it says the key to breaking vendor lock-in is to commit fully to a single technology vendor, be it a cloud software provider, a social network, or our favorite sharing app. It seems controversial on the surface, but I wanted to jot down some quick notes. Maybe the approach is worth experimenting with?</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/07/rolling-clusters-for-deployment-with-terraform" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Rolling clusters for deployment with Terraform</h5>
#             <small class="card-text text-muted">Terraform enables more than infrastructure provisioning, you can even use it for deployments. Combine it with Packer, and you can have a very powerful immutable rolling deployment pipeline.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2018/07/working-with-terraform-modules" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Working with Terraform Modules</h5>
#             <small class="card-text text-muted">Terraform's Modules feature allows quickly building re-usable infrastructure templates to provision cloud environments repeatably. These notes will help set up a basic application for high-availability.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Jul 2018</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2017/10/getting-started-with-terraform" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Getting started with Terraform</h5>
#             <small class="card-text text-muted">A basic walkthrough of Terraform, the open-source, cloud-agnostic IaC tool by HashiCorp, the makers of Vagrant.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Oct 2017</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2017/09/upgrading-to-http2" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Upgrading to HTTP/2</h5>
#             <small class="card-text text-muted">It's about time we all move our web properties to HTTP/2. I list down some gotchas for those looking to migrate.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2017</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2017/09/http-security-headers-referrer-policy" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">HTTP security headers: Referrer-Policy</h5>
#             <small class="card-text text-muted">The web is a collection of inter-connected pages. This means chances are good that someone landing on your website is coming from another one, and when they leave your website, they take a lot of identifiable information with them. HTTP/2 allows you to control what happens to the referrer information when users leave your website.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2017</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2017/09/http-security-headers-x-content-type-options" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">HTTP security headers: X-Content-Type-Options</h5>
#             <small class="card-text text-muted">HTTP/2 introduced a new feature which basically just turns off an old default feature: the browser's hankering for figuring out the content type of a resource. Why and how should we turn it off?</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Sep 2017</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2017/09/http-security-headers-x-frame-options" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">HTTP security headers: X-Frame-Options</h5>
# ...
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/setting-custom-404-controller-in-phalcon" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Setting Custom 404 Controller in Phalcon</h5>
#             <small class="card-text text-muted">After CodeIgniter, Phalcon was the second PHP framework that I used. Blazingly fast and easy-to-use, one of the first things I did was create a custom 404 response controller.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/dns-record-types" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">DNS Record Types</h5>
#             <small class="card-text text-muted">A quick guide to the different DNS record types.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/securing-nginx-with-lets-encrypt-free-ssl-certificate" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Securing Nginx with Let's Encrypt Free SSL Certificate</h5>
#             <small class="card-text text-muted">Let's Encrypt is the self-hosted, industry-standard method of generating SSL certificates for your applications. If you're still paying for SSL certificates you're doing it wrong.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/vertical-scaling-vs-horizontal-scaling" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Vertical Scaling vs Horizontal Scaling</h5>
#             <small class="card-text text-muted">The differences between vertical and horizontal scaling may be simple, but they're critical to using cloud technologies effectively.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/essential-vim-keyboard-shortcuts" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Essential VIM Keyboard Shortcuts</h5>
#             <small class="card-text text-muted">A quick guide of essential VIM shortcuts.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/notes-on-aws-sqs" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Notes on AWS SQS</h5>
#             <small class="card-text text-muted">AWS SQS: what, why, how, why not.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/mysql-physical-backup-with-innobackupex" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">MySQL Physical Backup with Innobackupex</h5>
#             <small class="card-text text-muted">Innobackupex, part of Percona Xtrabackup, can perform physical backups of your MySQL databases.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/introduction-to-mysql-partitioning" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Introduction to MySQL Partitioning</h5>
#             <small class="card-text text-muted">MySQL partitioning basics: what, why, and how.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/introduction-to-fluentd" class="post-card">
#     <div class="card">
#
#         <img src="https://www.ayush.nz/static/images/img-thumbs/fluentd-architecture.jpg"
#             width="100%" height="310" alt="Card image for Introduction to Fluentd" />
#
#
#         <div class="card-body">
#             <h5 class="card-title">Introduction to Fluentd</h5>
#             <small class="card-text text-muted">The legacy logging infrastructure we have to deal with today was designed for humans and not machines, so a lot of effort is wasted trying to make backend systems understand log data.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/nano-keyboard-shortcuts" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">NANO Keyboard Shortcuts</h5>
#             <small class="card-text text-muted">A quick reference of NANO shortcuts.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/json-web-tokens" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">JSON Web Tokens</h5>
#             <small class="card-text text-muted">The following document assesses the possibility of using JWT (pronounced "jot") as a token exchange mechanism for APIs.</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
#     <div class="col">
#         <a href="/2016/08/hello-world" class="post-card">
#     <div class="card">
#
#
#         <div class="card-body">
#             <h5 class="card-title">Hello @World</h5>
#             <small class="card-text text-muted">Hello, World, you little blue thing...</small>
#         </div>
#         <div class="card-footer text-end">
#             <small class="text-muted">Aug 2016</small>
#         </div>
#
#     </div>
# </a>
#     </div>
#
# </div>
#   </div>
#
#   <!-- Javascript -->
# <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/js/bootstrap.min.js"
#     integrity="sha384-cVKIPhGWiC2Al4u+LWgxfKTRIcfu0JTxR+EQDz/bgldoEyl4H0zUF0QKbrJ0EcQF"
#     crossorigin="anonymous"></script>
# <!-- Plausible tracking code -->
# <script defer data-domain="ayush.nz" data-api="/elbisualp/api/event" src="/elbisualp/script.js"></script>
#
# <div class="row row-cols-1 footer-logo">
#     <a href="/" title="Home is where our story begins…"><img
#             src="https://www.ayush.nz/static/images/meta/favicon/android-chrome-192x192.png"
#             width="52" height="52" alt="Home is where our story begins…"></a>
# </div>
# <footer>
#     <div class="container">
#         <div class="row row-cols-1">
#             <div class="col">
#                 <p class="display-5 text-center">Enjoying my work?</p>
#                 <p class="display-6 text-center"><a href="https://www.buymeacoffee.com/ayushsharma" class="btn btn-lg btn-warning" target="_blank"><i class="fas fa-bell me-2"></i>Follow me</a> for updates in your inbox.</p>
#                 <p class="text-center">
#
#
#                     <a class="" href="https://www.ayush.nz/feed-everything.xml" title="RSS for Everything." target="_blank"><i class="fas fa-rss-square ms-2 me-1" id="subscribe"></i>Everything</a>
#
#                     <a class="" href="https://www.ayush.nz/feed-life-stuff.xml" title="RSS for Life Stuff." target="_blank"><i class="fas fa-rss-square ms-2 me-1" id="subscribe"></i>Life Stuff</a>
#
#                     <a class="" href="https://www.ayush.nz/feed-technology.xml" title="RSS for Technology." target="_blank"><i class="fas fa-rss-square ms-2 me-1" id="subscribe"></i>Technology</a>
#
#                     <a class="" href="https://www.ayush.nz/feed-video-games.xml" title="RSS for Video Games." target="_blank"><i class="fas fa-rss-square ms-2 me-1" id="subscribe"></i>Video Games</a>
#
#                     <a class="" href="https://www.ayush.nz/feed-meta.xml" title="RSS for META." target="_blank"><i class="fas fa-rss-square ms-2 me-1" id="subscribe"></i>META</a>
#
#                 </p>
#             </div>
#         </div>
#         <div class="row row-cols-1 row-cols-md-6 g-3">
#
#
#     <div class="col">
#         <a class="social-nav btn btn-success" rel="me" href="https://us6.list-manage.com/contact-form?u=768b89007e44f7f05c5e7539b&form_id=6eae4dbf8e9d1475f967c8447e3080ac" title="Email" target="_blank"><i class="fas fa-at mx-2"></i>Email</a>
#     </div>
#
#     <div class="col">
#         <a class="social-nav btn btn-success" rel="me" href="https://mastodon.nz/@ayushsharma22" title="Mastodon" target="_blank"><i class="fab fa-mastodon mx-2"></i>Mastodon</a>
#     </div>
#
#     <div class="col">
#         <a class="social-nav btn btn-success" rel="me" href="https://nz.linkedin.com/in/ayush-sharma-in" title="LinkedIn" target="_blank"><i class="fab fa-linkedin-in mx-2"></i>LinkedIn</a>
#     </div>
#
#     <div class="col">
#         <a class="social-nav btn btn-success" rel="me" href="https://gitlab.com/ayush-sharma" title="GitLab" target="_blank"><i class="fab fa-gitlab mx-2"></i>GitLab</a>
#     </div>
#
#     <div class="col">
#         <a class="social-nav btn btn-success" rel="me" href="https://steamcommunity.com/id/theovermage/" title="Steam" target="_blank"><i class="fab fa-steam-symbol mx-2"></i>Steam</a>
#     </div>
#
#     <div class="col">
#         <a class="social-nav btn btn-info" rel="me" href="https://www.buymeacoffee.com/ayushsharma" title="Support" target="_blank"><i class="fas fa-donate mx-2"></i>Support</a>
#     </div>
#
# </div>
#         <div class="row row-cols-1 row-cols-md-4 my-1 g-3">
#
#
#             <div class="col">
#                 <h3><span class="me-2">☕</span><a href="/life-stuff" title="A rich, vibrant, and heady assortment of panic attacks.">Life Stuff</a></h3>
#
#
#
#                 <a class="nav-link" href="https://www.ayush.nz/2021/07/my-10-favorite-books-so-far">My 10 favorite books so far! - 2021 edition</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2020/07/into-thin-air-the-story-of-indias-vaping-ban">Into thin air: The story of India's vaping ban.</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2016/08/douglas-noel-adams">Douglas Noel Adams</a>
#
#             </div>
#
#             <div class="col">
#                 <h3><span class="me-2">🎧</span><a href="/technology" title="Musings on Technology. Mostly tutorials and rants, some lunacy.">Technology</a></h3>
#
#
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/11/consuming-apis-responsibly">Consuming APIs responsibly</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/02/creating-article-series-posts-navigation-jekyll">Create a series of posts with navigation in Jekyll</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/01/practical-light-dark-mode-jekyll-bootstrap5">A practical guide to light and dark mode in Bootstrap 5 and Jekyll</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/01/nemo-file-manager-ubuntu-20.04-linux-nautilus-alternative">Nemo - The Ubuntu file manager you didn’t know you needed</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/01/announcing-fediverse-to">Announcing Fediverse.to!</a>
#
#             </div>
#
#             <div class="col">
#                 <h3><span class="me-2">🕹️</span><a href="/video-games" title="My trusty companion when Technology and Life Stuff can go eff themselves.">Video Games</a></h3>
#
#
#
#                 <a class="nav-link" href="https://www.ayush.nz/2009/06/rise-of-the-argonauts-review">Rise of the Argonauts review</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2005/07/a-guide-to-better-town-management-in-caesar-iii">A guide to better town management in Caesar III</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2005/07/metal-fatigue-review">Metal Fatigue review</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2005/07/command-and-conquer-red-alert-2-review">Command and Conquer: Red Alert 2 review</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2005/06/top-10-tips-for-command-and-conquer-red-alert-2">Top 10 tips for Command and Conquer: Red Alert 2!</a>
#
#             </div>
#
#             <div class="col">
#                 <h3><span class="me-2">🛠️</span><a href="/meta" title="A journey towards the perfect digital garden.">META</a></h3>
#
#
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/02/creating-article-series-posts-navigation-jekyll">Create a series of posts with navigation in Jekyll</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2022/01/practical-light-dark-mode-jekyll-bootstrap5">A practical guide to light and dark mode in Bootstrap 5 and Jekyll</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2021/11/easy-pretty-url-redirects-with-jekyll-and-netlify">Easy pretty URL redirects with Jekyll and Netlify</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2021/11/linking-jekyll-pages-back-to-their-git-source-code">Linking Jekyll pages back to their Git source code</a>
#
#                 <a class="nav-link" href="https://www.ayush.nz/2021/11/optimising-jpg-and-png-images-for-a-jekyll-blog">Optimising JPG and PNG images for a Jekyll website</a>
#
#             </div>
#
#         </div>
#         <div class="row row-cols-1 row-cols-md-4 g-3">
#             <div class="col">
#                 <a rel="license" class="meta-nav" href="http://creativecommons.org/licenses/by-sa/4.0/" target="_blank"
#                     title="Creative Commons Attribution-ShareAlike 4.0">Licence cc-by-sa-4</a>
#             </div>
#             <div class="col">
#                 <a class="meta-nav" href="https://gitlab.com/ayush-sharma/ayushsharma-in" target="_blank">View source code</a>
#             </div>
#             <div class="col">
#                 <a class="meta-nav" href="/stats">Stats for nerds</a>
#             </div>
#             <div class="col">
#                 <a class="meta-nav" href="/about#privacy_policy">Privacy policy</a>
#             </div>
#         </div>
#     </div>
# </footer>
#
# </body>
#
# </html>

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint

url = 'https://notes.ayushsharma.in/technology'
data = requests.get(url)

my_data = []

html = BeautifulSoup(data.text, 'html.parser')
articles = html.select('a.post-card')

for article in articles:

    title = article.select('.card-title')[0].get_text()
    excerpt = article.select('.card-text')[0].get_text()
    pub_date = article.select('.card-footer small')[0].get_text()

    my_data.append({"title": title, "excerpt": excerpt, "pub_date": pub_date})

pprint(my_data)
# Out:
# [{'excerpt': "Or: Etiquette and table manners for pinging other people's "
#              'servers.',
#   'pub_date': 'Nov 2022',
#   'title': 'Consuming APIs responsibly'},
#  {'excerpt': 'Add Jekyll posts into a series with series navigation.',
#   'pub_date': 'Feb 2022',
#   'title': 'Create a series of posts with navigation in Jekyll'},
#  {'excerpt': 'Implementing light and dark mode on your Bootstrap 5 + Jekyll '
#              'website.',
#   'pub_date': 'Jan 2022',
#   'title': 'A practical guide to light and dark mode in Bootstrap 5 and '
#            'Jekyll'},
#  {'excerpt': 'Celebrate 2022 with a shiny new file manager for Ubuntu!',
#   'pub_date': 'Jan 2022',
#   'title': 'Nemo - The Ubuntu file manager you didn’t know you needed'},
#  {'excerpt': "I've been working on a search engine for Fediverse instances!",
#   'pub_date': 'Jan 2022',
#   'title': 'Announcing Fediverse.to!'},
#  {'excerpt': 'Combine Jekyll and Netlify to create pretty URL redirects as '
#              'easy as 1-2-3.',
#   'pub_date': 'Nov 2021',
#   'title': 'Easy pretty URL redirects with Jekyll and Netlify'},
#  {'excerpt': 'Add a link back to the public Git hosting link for any static '
#              'Jekyll blog.',
#   'pub_date': 'Nov 2021',
#   'title': 'Linking Jekyll pages back to their Git source code'},
#  {'excerpt': 'Use CLI tools to generate resized and optimised thumbnails for '
#              'articles header images.',
#   'pub_date': 'Nov 2021',
#   'title': 'Optimising JPG and PNG images for a Jekyll website'},
#  {'excerpt': 'Display search results from any JSON data object in the browser '
#              'using Lunr.js.',
#   'pub_date': 'Nov 2021',
#   'title': 'Quick and easy client-side JavaScript search with Lunr.js'},
#  {'excerpt': 'Blur the line between desktop and web by letting the OS style '
#              'your website or webapp.',
#   'pub_date': 'Oct 2021',
#   'title': 'Creating light and dark themes for websites the right way using '
#            'prefers-color-scheme'},
#  {'excerpt': 'Notion is an awesome life manager. And Mastodon is great for '
#              'decentralised internet shenanigans. With Nativefier, I can now '
#              'enjoy them as apps on Ubuntu 20.04.',
#   'pub_date': 'Oct 2021',
#   'title': 'Make Linux apps for Notion, Mastodon, or any web app using '
#            'Nativefier'},
#  {'excerpt': 'Auto-generate Jekyll configuration files with content and avoid '
#              'creating an API backend.',
#   'pub_date': 'Oct 2021',
#   'title': 'Inserting dynamic data into Jekyll static sites using Python or '
#            'Bash'},
#  {'excerpt': 'Ansible is the answer to custom scripts and tooling that '
#              'eventually snowball into a kludge which breaks more things than '
#              'it fixes.',
#   'pub_date': 'Aug 2021',
#   'title': 'Introduction to Ansible'},
#  {'excerpt': 'What is YAML and why is it about time we started using it?',
#   'pub_date': 'Aug 2021',
#   'title': 'Introduction to YAML'},
#  {'excerpt': 'Jekyll is a framework for building websites - write your content '
#              'in Markdown, use HTML/CSS for structure and presentation, and '
#              'Jekyll compiles it all into static HTML. No servers. No '
#              'backends. No fuss.',
#   'pub_date': 'Aug 2021',
#   'title': 'Introduction to Jekyll'},
#  {'excerpt': 'If you ever need to test an app and a database, did you know you '
#              'can use Vagrant to bring up multiple testing machines at once? '
#              "Here's how.",
#   'pub_date': 'Aug 2021',
#   'title': 'Multi-machine Setup and Configuration with Vagrant'},
#  {'excerpt': 'Ansible works well to provision a Vagrant box with everything '
#              'installed from the get-go.',
#   'pub_date': 'Aug 2021',
#   'title': 'Provisioning with Vagrant'},
#  {'excerpt': 'Vagrant helps you run other operating systems on your computer, '
#              'meaning you can build things, test things, and do crazy shit '
#              'without blowing up your own system.',
#   'pub_date': 'Aug 2021',
#   'title': 'Introduction to Vagrant'},
#  {'excerpt': 'Web-scraping is a useful but often neglected technical skill. '
#              'The BeautifulSoup library in Python makes extracting HTML from '
#              'web pages easy. Do with that what you will ;)',
#   'pub_date': 'Aug 2021',
#   'title': 'A Guide to Web Scraping in Python using BeautifulSoup'},
#  {'excerpt': "I recently discovered that Jekyll's config.yml can be used to "
#              "define custom variables for reusing content. I feel like I've "
#              'been living under a rock all this time. But to err over and over '
#              'again is human.',
#   'pub_date': 'Aug 2021',
#   'title': 'Using variables in Jekyll to define custom content'},
#  {'excerpt': "In this article, I'll highlight some ideas for Jekyll "
#              'collections, blog category pages, responsive web-design, and '
#              'netlify.toml to make static website maintenance a breeze.',
#   'pub_date': 'Jul 2021',
#   'title': 'The evolution of ayushsharma.in: Jekyll, Bootstrap, Netlify, '
#            'static websites, and responsive design.'},
#  {'excerpt': "These are the top 5 lessons I've learned after 5 years of "
#              'Terraform-ing.',
#   'pub_date': 'Jul 2021',
#   'title': '5 key best practices for sane and usable Terraform setups'},
#  {'excerpt': 'In this article I explore Checkov, a static code analysis tool '
#              'for Terraform.',
#   'pub_date': 'Jul 2021',
#   'title': 'Cloud Infrastructure SAST: Scanning Terraform for security '
#            'vulnerabilities and non-compliance using Checkov'},
#  {'excerpt': "I've just discovered that Terraform can deploy Helm Charts as "
#              "well. But I'm not sure if I like it.",
#   'pub_date': 'Jul 2021',
#   'title': 'Terraform + Helm: A match made in heaven/hell?'},
#  {'excerpt': 'In this tutorial, I will show you how to automatically create '
#              'multiple Applications in ArgoCD using ArgoCD!',
#   'pub_date': 'Jul 2021',
#   'title': 'Automating ArgoCD using ArgoCD!'},
#  {'excerpt': 'In this post we meet ArgoCD: a simple pull-based GitOps '
#              'deployment tool which syncs K8s manifest files with a cluster '
#              'for easy and no-nonsense deployments.',
#   'pub_date': 'Jul 2021',
#   'title': 'Getting started with ArgoCD'},
#  {'excerpt': 'Create parameterized AWS security groups quickly and '
#              'consistently with Terraform Registry.',
#   'pub_date': 'Sep 2020',
#   'title': 'Creating ready-to-use AWS Security Groups using Terraform '
#            'Registry, Named Groups, and Named Rules'},
#  {'excerpt': 'Create parameterized AWS VPCs quickly and consistently with '
#              'Terraform Registry.',
#   'pub_date': 'Sep 2020',
#   'title': 'Creating AWS VPCs in 2 minutes with Terraform Registry'},
#  {'excerpt': "Build and push Docker images to DockerHub using GitLab's "
#              'Pipelines feature.',
#   'pub_date': 'Jun 2020',
#   'title': 'Continuous delivery on GitLab: Pushing Docker images to DockerHub '
#            'using GitLab Pipelines'},
#  {'excerpt': 'A tutorial on how to configure automatic snapshots of '
#              'Elasticsearch using the in-built Snapshot Lifecycle Manager on '
#              'Google Compute Engine.',
#   'pub_date': 'Jun 2020',
#   'title': 'Configuring Elasticsearch snapshots using SLM on Google Compute '
#            'Engine'},
#  {'excerpt': 'Your time and attention is your primary resource, so deploy it '
#              'wisely.',
#   'pub_date': 'Jun 2020',
#   'title': '\u200b\u200bWorking From Home and Software Engineering'},
#  {'excerpt': '2020 is the year startups are trying to save aggresively on '
#              'cloud spend. I list down some key learnings based on my '
#              'experience.',
#   'pub_date': 'Apr 2020',
#   'title': '\u200b\u200bThe Virus \u200b😷\u200b and the Cloud \u200b⛅\u200b: '
#            'Tips on AWS cost-saving in these weird \u200b🤯\u200b times'},
#  {'excerpt': 'I love Bitbucket Pipelines, and debugging them on your laptop is '
#              "even easier thanks to Docker containers. I'll show you how to "
#              'debug Serverless deployments and diagnose broken builds.',
#   'pub_date': 'Mar 2020',
#   'title': 'Replicating Bitbucket Pipelines on your laptop for local '
#            'debugging'},
#  {'excerpt': "I'll show you how to allow one Bitbucket repo to clone another "
#              'during a Pipeline build.',
#   'pub_date': 'Feb 2020',
#   'title': 'Cloning another Bitbucket repository in Bitbucket Pipelines'},
#  {'excerpt': 'Git submodules makes it easy have repos for common dependencies, '
#              'but how to actually clone them in your Bitbucket Pipeline?',
#   'pub_date': 'Feb 2020',
#   'title': 'Deploying git submodules in Bitbucket Pipelines'},
#  {'excerpt': "I'll show you how to build a Docker image in a Pipeline and push "
#              'it to a container registry, in this case Amazon ECR.',
#   'pub_date': 'Aug 2019',
#   'title': 'Automating Amazon Elastic Container (ECR) container builds using '
#            'Bitbucket Pipelines'},
#  {'excerpt': 'AWS Cost & Usage Reports with AWS Athena are vital for '
#              "understanding cloud spend. I'll show you some handy Athena "
#              'queries to break things down.',
#   'pub_date': 'Aug 2019',
#   'title': 'Taming AWS costs with Cost and Usage Reports + AWS Athena'},
#  {'excerpt': "Bitbucket doesn't offer a dashboard yet, or an easy way to fetch "
#              'information for all your repos and Pipelines. So I wrote a handy '
#              "Python script for the job. It's great for configuring alerts or "
#              'building near-real-time dashboards!',
#   'pub_date': 'Jun 2019',
#   'title': 'Exporting Bitucket repositories and Pipelines with Python'},
#  {'excerpt': 'My very first programming language was Logo! I can still '
#              'remember guiding that fuzzy little on-screen turtle to draw '
#              'simple and complex shapes. So I found the Logo Python module and '
#              'took a walk down memory lane.',
#   'pub_date': 'Jun 2019',
#   'title': 'Rediscovering Logo with Bob the turtle'},
#  {'excerpt': 'The open-source Serverless framework makes it easy to build and '
#              "deploy Lambda stacks. I'll walk you through deploying Serverless "
#              'apps automatically using Pipelines.',
#   'pub_date': 'May 2019',
#   'title': 'Automating Serverless framework deployments using Bitbucket '
#            'Pipelines'},
#  {'excerpt': 'Pipes is another great Continuous Delivery feature in Bitbucket: '
#              'pre-built, ready-to-use, and parameterized deployment jobs.',
#   'pub_date': 'May 2019',
#   'title': 'Automating AWS Lambda deployments using Bitbucket Pipelines and '
#            'Bitbucket Pipes'},
#  {'excerpt': 'Notes on implementing the basic Exchange sort algorithms in '
#              'Python.',
#   'pub_date': 'Mar 2019',
#   'title': 'Algorithms in Python: Exchange Sorts'},
#  {'excerpt': 'The Phoenix Project is one of the most approachable books for '
#              'DevOps available today. Highly recommended, especially if you '
#              "don't already know Conway's Law.",
#   'pub_date': 'Jan 2019',
#   'title': 'The Three Ways of DevOps: Notes on The Phoenix Project'},
#  {'excerpt': 'My Udacity Python Nanodegree introduced using NumPy to handle '
#              'large arrays and datasets in Python. I put some notes togther '
#              'for referencing later.',
#   'pub_date': 'Oct 2018',
#   'title': 'Working with NumPy in Python'},
#  {'excerpt': 'Some quick notes describing the basic data types in Python3 and '
#              'their features.',
#   'pub_date': 'Sep 2018',
#   'title': 'Data Types in Python'},
#  {'excerpt': 'Tweet-Toot is my personal project, a Twitter relay for the '
#              'Mastodon social network. I recently dockerized the setup and put '
#              'these notes together to explain the process.',
#   'pub_date': 'Sep 2018',
#   'title': 'Dockerizing Tweet-Toot: A practical guide to deploying your app '
#            'using Docker'},
#  {'excerpt': 'SublimeText has some cool plugins for setting up a basic Jekyll '
#              'development environment. Take a look.',
#   'pub_date': 'Sep 2018',
#   'title': 'SublimeText 3 setup for Jekyll development'},
#  {'excerpt': "Gartner's Magic Quadrants was one of the the first industry "
#              "reports I read which covered where the cloud vendor's were "
#              'headed and what their strengths and weaknesses were. I took some '
#              'time to consolidate the Gartner findings over the last 5 years '
#              'for comparison.',
#   'pub_date': 'Sep 2018',
#   'title': "Gartner's Magic Quadrants: A summary of cloud "
#            'Infrastructure-as-a-Service providers over the last 5 years'},
#  {'excerpt': 'I joined the Mastodon social network in 2016 and felt a need for '
#              'building a Twitter relay. We all left the birdsite for many '
#              'reasons but not the people we met. So this project is a way to '
#              'bring some of them over to Mastodon, in practice if not in '
#              'spirit.',
#   'pub_date': 'Sep 2018',
#   'title': 'Tweet-Toot: Building a bot for Mastodon using Python'},
#  {'excerpt': 'I love Cloudflare, but after facing some issues with TTFB I '
#              'decided to move to StackPath, which proved to be a lot faster '
#              'and feature-rich.',
#   'pub_date': 'Jul 2018',
#   'title': 'Moving from CloudFlare to StackPath'},
#  {'excerpt': "I went through one of Gartner's reports, and it says the key to "
#              'breaking vendor lock-in is to commit fully to a single '
#              'technology vendor, be it a cloud software provider, a social '
#              'network, or our favorite sharing app. It seems controversial on '
#              'the surface, but I wanted to jot down some quick notes. Maybe '
#              'the approach is worth experimenting with?',
#   'pub_date': 'Jul 2018',
#   'title': 'Understanding vendor lock-in and breaking the cycle'},
#  {'excerpt': 'Terraform enables more than infrastructure provisioning, you can '
#              'even use it for deployments. Combine it with Packer, and you can '
#              'have a very powerful immutable rolling deployment pipeline.',
#   'pub_date': 'Jul 2018',
#   'title': 'Rolling clusters for deployment with Terraform'},
#  {'excerpt': "Terraform's Modules feature allows quickly building re-usable "
#              'infrastructure templates to provision cloud environments '
#              'repeatably. These notes will help set up a basic application for '
#              'high-availability.',
#   'pub_date': 'Jul 2018',
#   'title': 'Working with Terraform Modules'},
#  {'excerpt': 'A basic walkthrough of Terraform, the open-source, '
#              'cloud-agnostic IaC tool by HashiCorp, the makers of Vagrant.',
#   'pub_date': 'Oct 2017',
#   'title': 'Getting started with Terraform'},
#  {'excerpt': "It's about time we all move our web properties to HTTP/2. I list "
#              'down some gotchas for those looking to migrate.',
#   'pub_date': 'Sep 2017',
#   'title': 'Upgrading to HTTP/2'},
#  {'excerpt': 'The web is a collection of inter-connected pages. This means '
#              'chances are good that someone landing on your website is coming '
#              'from another one, and when they leave your website, they take a '
#              'lot of identifiable information with them. HTTP/2 allows you to '
#              'control what happens to the referrer information when users '
#              'leave your website.',
#   'pub_date': 'Sep 2017',
#   'title': 'HTTP security headers: Referrer-Policy'},
#  {'excerpt': 'HTTP/2 introduced a new feature which basically just turns off '
#              "an old default feature: the browser's hankering for figuring out "
#              'the content type of a resource. Why and how should we turn it '
#              'off?',
#   'pub_date': 'Sep 2017',
#   'title': 'HTTP security headers: X-Content-Type-Options'},
#  {'excerpt': 'Inline-frames enable very basic phishing attacks. You can just '
#              "include a bank's main website within your own website and lure "
#              'the user to handover their passwords. HTTP2/ comes with built-in '
#              'protection against this kind of threat.',
#   'pub_date': 'Sep 2017',
#   'title': 'HTTP security headers: X-Frame-Options'},
#  {'excerpt': 'HSTS is a security feature which prevents users from accessing '
#              'your website over non-secure HTTP. It comes with HTTP/2, is easy '
#              "to turn on, but very hard to turn off. Here's the why and how.",
#   'pub_date': 'Sep 2017',
#   'title': 'HTTP security headers: HTTP-Strict-Transport-Security'},
#  {'excerpt': "HTTP/2 comes with built-in protection for XSS. Here's what it "
#              'does and how to turn it on.',
#   'pub_date': 'Sep 2017',
#   'title': 'HTTP security headers: X-XSS-Protection'},
#  {'excerpt': "HTTP/2's CSP let's you define a white-list of what's allowed and "
#              "what's blocked on your website. This lets browsers block "
#              "third-party trackers which try to annoy/harm your users. Here's "
#              'the why and how.',
#   'pub_date': 'Sep 2017',
#   'title': 'HTTP security headers: Content-Security-Policy'},
#  {'excerpt': 'I added the Disqus commenting platform to my blog some time ago. '
#              'And then I found out that it was loading WAY TOO MANY tracking '
#              'cookies inline and profiling my website users. This is how you '
#              'build Orwellian software. And shitty software.',
#   'pub_date': 'Sep 2017',
#   'title': "I'm killing Disqus comments on my blog. Here's why."},
#  {'excerpt': 'Slack has become a favorite of DevOps/SRE teams across the '
#              "globe. It's a very easy-to-use and programmatic messaging "
#              "platform. Here's the quick and easy process to posting messages "
#              'to your Slack group from Python.',
#   'pub_date': 'Sep 2017',
#   'title': 'Posting messages to Slack using incoming webhooks and Python3 '
#            'Requests API'},
#  {'excerpt': 'Packer is an amazing golden image builder. Ansible is a great '
#              "deployment tool. So let's use them together!",
#   'pub_date': 'Sep 2017',
#   'title': 'Using Packer and Ansible to create immutable servers, deploying '
#            'code, and recycling instances'},
#  {'excerpt': 'Packer. Basically Docker for whole VMs. Another great tool by '
#              'HashiCorp, this one modernises an old formula but retains the '
#              'simplicity. Building immutable servers was never this easy.',
#   'pub_date': 'Sep 2017',
#   'title': 'Getting started with Packer'},
#  {'excerpt': 'I took a walk down memory lane to try and figure out how much my '
#              'daily work has changed. The concepts are still the same, but the '
#              'tools have become bigger, because our needs have shifted '
#              'dramatically over the years.',
#   'pub_date': 'Sep 2017',
#   'title': "The different ways I've deployed code over the years: the road to "
#            'Immutable Servers'},
#  {'excerpt': 'A quick script for ad-hoc health-checking of load balancer '
#              'instances.',
#   'pub_date': 'Sep 2017',
#   'title': 'Testing AWS Elastic Load Balancer health check endpoints with '
#            'Python'},
#  {'excerpt': 'I recently discovered InfluxDB as a great write-heavy database '
#              'for storing metrics. These are my notes on monitoring the golden '
#              'signals in Nginx using Collectd and InfluxDB.',
#   'pub_date': 'Aug 2017',
#   'title': 'Complete Nginx Monitoring with Collectd and InfluxDB'},
#  {'excerpt': "Because why not? Here's how to build your Jekyll website and "
#              'deploy it to a VM of your choice.',
#   'pub_date': 'Aug 2017',
#   'title': 'Deploying Jekyll blog automatically using Bitbucket Pipelines'},
#  {'excerpt': 'If you ever need to migrate a MySQL database to InfluxDB, say if '
#              'you were using MySQL as a metrics database because you were too '
#              'busy not knowing Influx even existed, then this handy Python '
#              'script can do the job and take care of schema migrations too.',
#   'pub_date': 'Aug 2017',
#   'title': 'Migrating MySQL database tables to InfluxDB'},
#  {'excerpt': 'A handy bash script to backup your InfluxDB database to AWS S3; '
#              'great for cron jobs.',
#   'pub_date': 'Aug 2017',
#   'title': 'Backing up InfluxDB databases to S3'},
#  {'excerpt': 'Grafana provides out-of-the-box support for InfluxDB, so '
#              "visualising the metrics you're collecting using Collectd, etc., "
#              "is straightforward. Here's how to do it.",
#   'pub_date': 'Aug 2017',
#   'title': 'Setting Up Grafana to use Collectd and InfluxDB'},
#  {'excerpt': 'A quick copy-paste-able process for installing Collectd and '
#              'InfluxDB on your Mac for some local testing.',
#   'pub_date': 'Aug 2017',
#   'title': 'Setting up Collectd and InfluxDB on Mac OS X'},
#  {'excerpt': 'A quick comparison of relational vs time-series databases, '
#              'followed by a brief hands-on tutorial for InfluxDB on a local '
#              'Mac OS.',
#   'pub_date': 'Aug 2017',
#   'title': 'Getting Started with time-series data using InfluxDB'},
#  {'excerpt': 'Collectd, a C-based daemon, is a fast and lightweight metrics '
#              'shipper.',
#   'pub_date': 'Aug 2017',
#   'title': 'Getting started with server metrics collection with Collectd'},
#  {'excerpt': 'A very basic reality of computer networking is that... it fails. '
#              'And when it does, there are ways to retry your connections to '
#              'make life easier for you and other clients as well.',
#   'pub_date': 'Aug 2017',
#   'title': 'Retry Strategies for Transient Failures'},
#  {'excerpt': 'AWS Elastic load balancers do their job well, but they can get '
#              'pricey. So naturally I tried using Route53 for load balancing '
#              'traffic. It was a lot harder than I thought, and while this '
#              "experiment didn't succeed, I'm noting my approach here for "
#              'better luck next time.',
#   'pub_date': 'Aug 2017',
#   'title': 'Using Route 53 as a Load Balancer'},
#  {'excerpt': 'A handy bash script to backup all MySQL databases to AWS S3.',
#   'pub_date': 'Aug 2017',
#   'title': 'MySQL Database backups to S3'},
#  {'excerpt': 'The title really says it all: exporting data from JSON and '
#              'ingesting into Sqlite3.',
#   'pub_date': 'Apr 2017',
#   'title': 'Mastodon Users and Instances in Sqlite3 Using Python'},
#  {'excerpt': "I installed mutt to send email from the command-line. It's fast "
#              'and the CLI switches are memorable. Worth a look if you use the '
#              'CLI for sending emails a lot.',
#   'pub_date': 'Apr 2017',
#   'title': 'The Ultimate Guide to Using Mail in Linux'},
#  {'excerpt': 'You get 3 guesses for what the solution could be...',
#   'pub_date': 'Mar 2017',
#   'title': "Fixing ValueError('unknown locale: %s' % localename) in Python"},
#  {'excerpt': 'Xinetd is a light-weight and straightfoward HTTP server. Not as '
#              "powerful as Nginx, but it's great for simple things like "
#              'configuring health checks.',
#   'pub_date': 'Mar 2017',
#   'title': 'Getting Started with Xinetd'},
#  {'excerpt': 'The Maxmind GeoIP database is useful for looking up the country '
#              'and ISP information for an IP address.',
#   'pub_date': 'Mar 2017',
#   'title': 'Getting City, Country and ISP of an IP address using Maxmind '
#            'GeoIP'},
#  {'excerpt': 'I pulled the data for technology incidents for the major cloud '
#              'services. The findings were pretty interesting.',
#   'pub_date': 'Mar 2017',
#   'title': 'AWS, GCS, Azure and Digital Ocean incidents by service in 2016'},
#  {'excerpt': 'These have been the confessions of a firefighter who ignored the '
#              'smoke.',
#   'pub_date': 'Mar 2017',
#   'title': 'I Have Something to Say II'},
#  {'excerpt': 'At work, one of my recent projects involved setting up a '
#              'multi-region failover with weighted-routing support. Thankfully, '
#              "Route53 has all of these built-in. Here's how to do it.",
#   'pub_date': 'Mar 2017',
#   'title': 'Using Weighted, Geo and Fail-over Routeing in Route 53'},
#  {'excerpt': "It's 2017 and the cloud has matured by leaps and bounds. So do "
#              'we still need staging servers?',
#   'pub_date': 'Mar 2017',
#   'title': 'You still might need a staging server in 2017'},
#  {'excerpt': 'I pulled the data for technology incidents on the major cloud '
#              'platforms. The findings were pretty interesting.',
#   'pub_date': 'Mar 2017',
#   'title': 'AWS, GCS, Azure and Digital Ocean incidents in 2016'},
#  {'excerpt': 'Ten years from now, if or when I am in another job, no one is '
#              'going to care whether I ran my production servers with my heart '
#              'and soul. They will care if I saved money, they will care if I '
#              'ran it efficiently, but you can do those things while still '
#              'compromising your values.',
#   'pub_date': 'Mar 2017',
#   'title': 'I Have Something to Say'},
#  {'excerpt': 'A step-by-step guide for connecting 2 AWS VPSs using self-hosted '
#              'StrongSwan VPNs.',
#   'pub_date': 'Feb 2017',
#   'title': 'Connecting VPCs in 2 AWS Regions (Site-to-site VPN)'},
#  {'excerpt': 'These are instructions for installing PHP7, MySQL 5.7 and Nginx '
#              '1.10 on Ubuntu 16.04. Very copy-paste-able.',
#   'pub_date': 'Feb 2017',
#   'title': 'Installing PHP 7 FPM + MySQL 5.7 + Nginx 1.10 on Ubuntu 16.04'},
#  {'excerpt': 'Some notes on Logical Volume Manager. What it is, why it is, and '
#              'how to use it.',
#   'pub_date': 'Feb 2017',
#   'title': 'Working with Logical Volume Manager (LVM)'},
#  {'excerpt': "Logrotate is one of those built-in Linux things that we don't "
#              'use often enough. Rotating logs, archiving them to S3, pushing '
#              "them to some remote server/endpoint, etc. It's all doable with "
#              'Logrotate.',
#   'pub_date': 'Jan 2017',
#   'title': 'Fiddling with Logrotate'},
#  {'excerpt': 'Route53: what, why, how, why not.',
#   'pub_date': 'Jan 2017',
#   'title': 'AWS Route 53 Notes'},
#  {'excerpt': 'I ran hdparm and dd on GP2, PIOPS, SC1, ST1, and Magnetic EBS '
#              'volumes. Check out the results.',
#   'pub_date': 'Jan 2017',
#   'title': 'AWS EBS Types Read/Write Benchmarks'},
#  {'excerpt': 'AWS spot instances provide 90% savings over on-demand servers. '
#              'The downside? AWS can yank them whenever they want and you have '
#              '2 minutes to back things up. How do you know when the starting '
#              'pistol fires?',
#   'pub_date': 'Oct 2016',
#   'title': 'Logging AWS spot instance termination'},
#  {'excerpt': "If you're using a Lua module with Nginx, then decompressing "
#              'GZIPped data requires some extra handling.',
#   'pub_date': 'Oct 2016',
#   'title': 'Decompressing request using GZIP with Nginx'},
#  {'excerpt': "It's pretty hard to compress output with GZIP in PHP 5.3, but in "
#              "case you ever need to, here's how.",
#   'pub_date': 'Oct 2016',
#   'title': 'Compressing output using GZIP with PHP 5.3'},
#  {'excerpt': "I'll explore the basics of self-hosted load-balancing with Nginx "
#              'using a convenient testing setup using Vagrant.',
#   'pub_date': 'Aug 2016',
#   'title': 'Introduction to Load-balancing with Nginx'},
#  {'excerpt': "Here's how to read a response JSON web token in PHP Phalcon.",
#   'pub_date': 'Aug 2016',
#   'title': 'Reading JWT token in Phalcon'},
#  {'excerpt': 'After CodeIgniter, Phalcon was the second PHP framework that I '
#              'used. Blazingly fast and easy-to-use, one of the first things I '
#              'did was create a custom 404 response controller.',
#   'pub_date': 'Aug 2016',
#   'title': 'Setting Custom 404 Controller in Phalcon'},
#  {'excerpt': 'A quick guide to the different DNS record types.',
#   'pub_date': 'Aug 2016',
#   'title': 'DNS Record Types'},
#  {'excerpt': "Let's Encrypt is the self-hosted, industry-standard method of "
#              "generating SSL certificates for your applications. If you're "
#              "still paying for SSL certificates you're doing it wrong.",
#   'pub_date': 'Aug 2016',
#   'title': "Securing Nginx with Let's Encrypt Free SSL Certificate"},
#  {'excerpt': 'The differences between vertical and horizontal scaling may be '
#              "simple, but they're critical to using cloud technologies "
#              'effectively.',
#   'pub_date': 'Aug 2016',
#   'title': 'Vertical Scaling vs Horizontal Scaling'},
#  {'excerpt': 'A quick guide of essential VIM shortcuts.',
#   'pub_date': 'Aug 2016',
#   'title': 'Essential VIM Keyboard Shortcuts'},
#  {'excerpt': 'AWS SQS: what, why, how, why not.',
#   'pub_date': 'Aug 2016',
#   'title': 'Notes on AWS SQS'},
#  {'excerpt': 'Innobackupex, part of Percona Xtrabackup, can perform physical '
#              'backups of your MySQL databases.',
#   'pub_date': 'Aug 2016',
#   'title': 'MySQL Physical Backup with Innobackupex'},
#  {'excerpt': 'MySQL partitioning basics: what, why, and how.',
#   'pub_date': 'Aug 2016',
#   'title': 'Introduction to MySQL Partitioning'},
#  {'excerpt': 'The legacy logging infrastructure we have to deal with today was '
#              'designed for humans and not machines, so a lot of effort is '
#              'wasted trying to make backend systems understand log data.',
#   'pub_date': 'Aug 2016',
#   'title': 'Introduction to Fluentd'},
#  {'excerpt': 'A quick reference of NANO shortcuts.',
#   'pub_date': 'Aug 2016',
#   'title': 'NANO Keyboard Shortcuts'},
#  {'excerpt': 'The following document assesses the possibility of using JWT '
#              '(pronounced "jot") as a token exchange mechanism for APIs.',
#   'pub_date': 'Aug 2016',
#   'title': 'JSON Web Tokens'},
#  {'excerpt': 'Hello, World, you little blue thing...',
#   'pub_date': 'Aug 2016',
#   'title': 'Hello @World'}]

# %% [markdown]
# #Another Example

# %%
#importing the BeautifulSoup Library  
  
import bs4  
import requests  
  
#Creating the requests  
  
res = requests.get("https://en.wikipedia.org/wiki/Machine_learning")  
print("The object type:",type(res))  
  
# Convert the request object to the Beautiful Soup Object  
soup = bs4.BeautifulSoup(res.text,'html5lib')  
print("The object type:",type(soup))
# Out:
# The object type: <class 'requests.models.Response'>
# The object type: <class 'bs4.BeautifulSoup'>

# %%
soup.select('.mw-headline')  
for i in soup.select('.mw-headline'):  
  print(i.text,end = ',')
# Out:
# Overview,History and relationships to other fields,Artificial intelligence,Data mining,Generalization,Statistics,Physics, Theory,Approaches,Supervised learning,Unsupervised learning,Semi-supervised learning,Reinforcement learning,Dimensionality reduction,Other types,Self-learning,Feature learning,Sparse dictionary learning,Anomaly detection,Robot learning,Association rules,Models,Artificial neural networks,Decision trees,Support-vector machines,Regression analysis,Bayesian networks,Gaussian processes,Genetic algorithms,Training models,Federated learning,Applications,Limitations,Bias,Explainability,Overfitting,Other limitations and vulnerabilities,Model assessments,Ethics,Hardware,Neuromorphic/Physical Neural Networks,Embedded Machine Learning,Software,Free and open-source software,Proprietary software with free and open-source editions,Proprietary software,Journals,Conferences,See also,References,Sources,Further reading,External links,

# %% [markdown]
# #Flipkart

# %%
from bs4 import BeautifulSoup as soup  
from urllib.request import urlopen as uReq  
  
# Request from the webpage  
myurl = "https://www.flipkart.com/search?q=iphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"  
  
  
uClient  = uReq(myurl)  
page_html = uClient.read()  
uClient.close()  
  
page_soup = soup(page_html, features="html.parser")  
  
# print(soup.prettify(containers[0]))  
  
# This variable held all html of webpage  
containers = page_soup.find_all("div",{"class": "_3O0U0u"})  
# container = containers[0]  
# # print(soup.prettify(container))  
#  
# price = container.find_all("div",{"class": "col col-5-12 _2o7WAb"})  
# print(price[0].text)  
#  
# ratings = container.find_all("div",{"class": "niH0FQ"})  
# print(ratings[0].text)  
#  
# #  
# # print(len(containers))  
# print(container.div.img["alt"])  
  
# Creating CSV File that will store all data   
filename = "product1.csv"  
f = open(filename,"w")  
  
headers = "Product_Name,Pricing,Ratings\n"  
f.write(headers)  
  
for container in containers:  
    product_name = container.div.img["alt"]  
  
    price_container = container.find_all("div", {"class": "col col-5-12 _2o7WAb"})  
    price = price_container[0].text.strip()  
  
    rating_container = container.find_all("div",{"class":"niH0FQ"})  
    ratings = rating_container[0].text  
  
    print("product_name:"+product_name)  
    print("price:"+price)  
    print("ratings:"+ str(ratings))  
  
    edit_price = ''.join(price.split(','))  
    sym_rupee = edit_price.split("?")  
    add_rs_price = "Rs"+sym_rupee[1]  
    split_price = add_rs_price.split("E")  
    final_price = split_price[0]  
  
    split_rating = str(ratings).split(" ")  
    final_rating = split_rating[0]  
  
    print(product_name.replace(",", "|")+","+final_price+","+final_rating+"\n")  
    f.write(product_name.replace(",", "|")+","+final_price+","+final_rating+"\n")  
  
f.close()

# %%
import pandas as pd

df = pd.read_csv("/content/product1.csv")
df.tail()
# Out:
# Empty DataFrame
# Columns: [Product_Name, Pricing, Ratings]
# Index: []

# %% [markdown]
# #Javapoint Example

# %%
# importing the libraries  
from bs4 import BeautifulSoup  
import requests  
  
url="https://www.javatpoint.com/"  
  
# Make a GET request to fetch the raw HTML content  
html_content = requests.get(url).text  
  
# Parse the html content  
soup = BeautifulSoup(html_content, "html5lib")  
print(soup.prettify()) # print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="https://static.javatpoint.com/images/favicon2.png" rel="SHORTCUT ICON"/>
#   <title>
#    Tutorials List - Javatpoint
#   </title>
#   <meta content="javatpoint, java tutorial, core java tutorial, beginners, professionals" name="keywords"/>
#   <meta content="Tutorials, Free Online Tutorials, Javatpoint provides tutorials and interview questions of all technology like java tutorial, android, java frameworks, javascript, ajax, core java, sql, python, php, c language etc. for beginners and professionals." name="description"/>
#   <link href="https://clients1.google.com" rel="preconnect"/>
#   <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://static.javatpoint.com" rel="preconnect"/>
#   <link href="https://www.google.com" rel="preconnect"/>
#   <link href="https://feedify.net" rel="preconnect"/>
#   <link href="https://clients1.google.com" rel="dns-prefetch"/>
#   <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://static.javatpoint.com" rel="dns-prefetch"/>
#   <link href="https://www.google.com" rel="dns-prefetch"/>
#   <link href="https://feedify.net" rel="dns-prefetch"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="https://www.javatpoint.com" rel="canonical"/>
#   <meta content="#4CAF50" name="theme-color"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Tutorials - Javatpoint" name="twitter:title" property="og:title"/>
#   <meta content="Tutorials, Free Online Tutorials, Javatpoint provides tutorials and interview questions of all technology like java tutorial, android, java frameworks, javascript, ajax, core java, sql, python, php, c language etc. for beginners and professionals." name="twitter:description" property="og:description"/>
#   <meta content="https://www.javatpoint.com" property="og:url"/>
#   <meta content="www.javatpoint.com" property="og:site_name"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@pagejavatpoint" name="twitter:site"/>
#   <meta content="www.javatpoint.com" name="twitter:domain"/>
#   <meta content="@pagejavatpoint" name="twitter:creator"/>
#   <meta content="NaYVz1vb9vgNxYaO7S6-16EJi3Q60kUuik1erUuFEYo" name="google-site-verification"/>
#   <style>
#    body{color:#202020}
#   </style>
#   <link href="https://static.javatpoint.com/link.css?v=5.4" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.javatpoint.com/manifest.json" rel="manifest"/>
#   <script data-cfasync="false" type="text/javascript">
#    (function (w, d) {
#   var siteId = "37780";
#   var targetElement =
#     d.getElementsByTagName("head")[0] || d.getElementsByTagName("body")[0];
#   var s = d.createElement("script");
#   s.src = "//cdn.adpushup.com/" + siteId + "/adpushup.js";
#   s.crossOrigin = "anonymous";
#   s.type = "text/javascript";
#   s.async = true;
#   targetElement.appendChild(s);
#   function sendErrorLog(log) {
#     var eventName = "script_error";
#     log.siteId = siteId;
#     var data = btoa(JSON.stringify(log));
#     var img = document.createElement("img");
#     img.src =
#       "https://aplogger.adpushup.com/log?event=HC_" + eventName + "&data=" + data;
#   }
#   var searchParams =
#     typeof URLSearchParams === "function" &&
#     new URLSearchParams(window.location.search);
#   if (searchParams) {
#     var isDebugModeOn = searchParams.has("apDebug");
#   }
#   w.addEventListener("error", function (event) {
#     try {
#       var filename = event.filename || "";
#       if (filename.indexOf("/" + siteId + "/adpushup.js") === -1) {
#         return;
#       }
#       var error = event.error;
#       if (error) {
#         var message = error.message;
#         var stack = error.stack;
#       }
#       message = message || event.message;
#       var log = {
#         message: message,
#         stack: stack || "",
#         timestamp: Math.floor(event.timeStamp),
#         type: "uncaughterror",
#       };
#       sendErrorLog(log);
#       !isDebugModeOn && event.preventDefault();
#     } catch (error) {}
#   });
#   w.addEventListener("unhandledrejection", function (event) {
#     var reason = event.reason;
#     if (typeof reason === "object") reason = JSON.stringify(reason);
#     var log = {
#       message: reason || "no reason found",
#       timestamp: Math.floor(event.timeStamp),
#       type: "unhandledrejection",
#     };
#     sendErrorLog(log);
#     !isDebugModeOn && event.preventDefault();
#   });
#   var ga = d.createElement("script");
#   ga.src = "https://www.googletagmanager.com/gtag/js?id=G-Z0TZ7TDHS1";
#   ga.type = "text/javascript";
#   ga.async = true;
#   targetElement.appendChild(ga);
#   w.dataLayer = window.dataLayer || [];
#   w.gtag = function () {
#     window.dataLayer.push(arguments);
#   };
#   w.gtag("js", new Date());
#   w.gtag("config", "G-Z0TZ7TDHS1", {
#     custom_map: { dimension1: "siteid" },
#   });
#   w.gtag("event", "script-call", {
#     send_to: "G-Z0TZ7TDHS1",
#     siteid: siteId,
#   });
#   s.onerror = function (msg) {
#     w.gtag("event", "ad-block", {
#       send_to: "G-Z0TZ7TDHS1",
#       siteid: siteId,
#     });
#   };
# })(window, document);
#   </script>
#  </head>
#  <body>
#   <div id="page" style="margin:-8px;background-color:#f5f5f4">
#    <div id="container">
#     <div class="header" id="headerpage">
#      <table style="width:100%;margin-bottom:5px">
#       <tbody>
#        <tr>
#         <td>
#          <div style="clear:both;float:left;width:230px;margin-top:15px;margin-left:20px">
#           <a href="https://www.javatpoint.com">
#            <img alt="Javatpoint Logo" src="https://static.javatpoint.com/images/logo/jtp_logo.png"/>
#           </a>
#          </div>
#          <div style="float:left;width:60%;">
#           <script>
#            (function() { var cx = '005383125436438536544:y1edweedxwi'; var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true; gcse.src = 'https://cse.google.com/cse.js?cx=' + cx; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s); })();
#           </script>
#           <gcse:search>
#           </gcse:search>
#          </div>
#         </td>
#        </tr>
#       </tbody>
#      </table>
#     </div>
#     <div class="headermobile">
#      <div style="margin-top:10px;margin-left:48px;padding:0px;text-align:left;">
#       <span style="float:left">
#        <a href="https://www.javatpoint.com">
#         <img alt="Javatpoint Logo" src="https://www.javatpoint.com/images/logo/jtp_logo.png"/>
#        </a>
#       </span>
#      </div>
#      <div style="margin:0px;padding:0px;clear:both">
#       <script>
#        (function() {
#     var cx = '005383125436438536544:y1edweedxwi';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#       </script>
#       <gcse:search>
#       </gcse:search>
#      </div>
#     </div>
#     <div id="link" style="clear:both">
#      <div class="ddsmoothmenu">
#       <ul>
#        <li>
#         <a href="https://www.javatpoint.com">
#          <img alt="home" src="https://static.javatpoint.com/images/icon/home.png"/>
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="python-tutorial">
#          <img alt="python" src="https://static.javatpoint.com/images/icon/python.png"/>
#          Python
#         </a>
#        </li>
#        <li>
#         <a href="java-tutorial">
#          <img alt="java" src="https://static.javatpoint.com/images/icon/java.png"/>
#          Java
#         </a>
#        </li>
#        <li>
#         <a href="javascript-tutorial">
#          <img alt="javascript" src="https://static.javatpoint.com/images/icon/js.png"/>
#          JavaScript
#         </a>
#        </li>
#        <li>
#         <a href="html-tutorial">
#          <img alt="html" src="https://static.javatpoint.com/images/icon/html.png"/>
#          HTML
#         </a>
#        </li>
#        <li>
#         <a href="sql-tutorial">
#          <img alt="sql" src="https://static.javatpoint.com/images/icon/sql.png"/>
#          SQL
#         </a>
#        </li>
#        <li>
#         <a href="php-tutorial">
#          <img alt="php" src="https://static.javatpoint.com/images/icon/php.png"/>
#          PHP
#         </a>
#        </li>
#        <li>
#         <a href="c-sharp-tutorial">
#          <img alt="c#" src="https://static.javatpoint.com/images/icon/csharp.png"/>
#          C#
#         </a>
#        </li>
#        <li>
#         <a href="cpp-tutorial">
#          <img alt="c++" src="https://static.javatpoint.com/images/icon/cpp.png"/>
#          C++
#         </a>
#        </li>
#        <li>
#         <a href="data-structure-tutorial">
#          <img alt="data structures" src="https://static.javatpoint.com/images/icon/ds.png"/>
#          DS
#         </a>
#        </li>
#        <li>
#         <a href="https://www.javatpoint.com/aptitude/quantitative">
#          <img alt="aptitude" src="https://static.javatpoint.com/images/icon/aptitude.png"/>
#          Aptitude
#         </a>
#        </li>
#        <li>
#         <a href="reasoning">
#          <img alt="reasoning" src="https://static.javatpoint.com/images/icon/reasoning.png"/>
#          Reasoning
#         </a>
#        </li>
#        <li>
#         <a href="selenium-tutorial">
#          <img alt="selenium" src="https://static.javatpoint.com/images/icon/selenium.png"/>
#          Selenium
#         </a>
#        </li>
#        <li>
#         <a href="dbms-tutorial">
#          <img alt="dbms" src="https://static.javatpoint.com/images/icon/dbms.png"/>
#          DBMS
#         </a>
#        </li>
#        <li>
#         <a href="c-programming-language-tutorial">
#          <img alt="c" src="https://static.javatpoint.com/images/icon/c.png"/>
#          C
#         </a>
#        </li>
#        <li>
#         <a href="android-tutorial">
#          <img alt="android" src="https://static.javatpoint.com/images/icon/android.png"/>
#          Android
#         </a>
#        </li>
#        <li>
#         <a href="interview-questions-and-answers">
#          <img alt="interview questions" src="https://static.javatpoint.com/images/icon/interview.png"/>
#          Interview Q
#         </a>
#        </li>
#       </ul>
#       <br style="clear: left"/>
#      </div>
#     </div>
#     <div class="onlycontent">
#      <div id="city">
#       <table>
#        <tbody>
#         <tr>
#          <td>
#           <ins class="adPushupAds" data-ac="..." data-adpcontrol="srgop" data-siteid="37780" data-ver="2">
#           </ins>
#           <script data-cfasync="false" type="text/javascript">
#            (function (w, d) { for (var i = 0, j = d.getElementsByTagName("ins"), k = j[i]; i < j.length; k = j[++i]){ if(k.className == "adPushupAds" && k.getAttribute("data-push") != "1") { ((w.adpushup = w.adpushup || {}).control = (w.adpushup.control || [])).push(k); k.setAttribute("data-push", "1");} } })(window, document);
#           </script>
#           <div>
#            <img alt="Youtube" class="lazyload" data-src="https://static.javatpoint.com/images/youtube-32.png" style="vertical-align:middle;"/>
#            <span class="h3" style="vertical-align:middle;font-size:22px">
#             For Videos Join Our Youtube Channel:
#             <a href="https://bit.ly/2FOeX6S" target="_blank">
#              Join Now
#             </a>
#            </span>
#           </div>
#           <hr class="hrhomebox"/>
#           <div class="homecol2">
#            <a href="https://training.javatpoint.com/" rel="noopener" target="_blank">
#             <img alt="javatpoint Training" class="lazyload" src="https://static.javatpoint.com/images/javatpoint-training91.png" style="margin-left:0px;width:350px;float:left"/>
#            </a>
#           </div>
#           <div class="homecol2">
#            <a href="https://training.javatpoint.com/" rel="noopener" target="_blank">
#             <img alt="Training Institute" class="lazyload" data-src="https://static.javatpoint.com/images/training/java-training1.png" style="margin-left:0px;width:350px;"/>
#            </a>
#           </div>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h1 class="h3">
#             Latest Tutorials
#            </h1>
#            <div class="firsthomecontent">
#             <a href="https://www.javatpoint.com/splunk">
#              <div class="homecontent">
#               <img alt="Splunk tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/splunk.png"/>
#               <p>
#                Splunk
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/spss">
#              <div class="homecontent">
#               <img alt="SPSS tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spss.png"/>
#               <p>
#                SPSS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/swagger">
#              <div class="homecontent">
#               <img alt="Swagger tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/swagger.png"/>
#               <p>
#                Swagger
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/t-sql">
#              <div class="homecontent">
#               <img alt="T-SQL tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/transact-sql.png"/>
#               <p>
#                Transact-SQL
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/tumblr">
#              <div class="homecontent">
#               <img alt="Tumblr tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/tumblr.png"/>
#               <p>
#                Tumblr
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/reactjs-tutorial">
#              <div class="homecontent">
#               <img alt="React tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/react.png"/>
#               <p>
#                ReactJS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/regex">
#              <div class="homecontent">
#               <img alt="Regex tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/regex.png"/>
#               <p>
#                Regex
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/reinforcement-learning">
#              <div class="homecontent">
#               <img alt="Reinforcement learning tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/react.png"/>
#               <p>
#                Reinforcement Learning
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/r-tutorial">
#              <div class="homecontent">
#               <img alt="R Programming tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/r-programming.png"/>
#               <p>
#                R Programming
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/rxjs">
#              <div class="homecontent">
#               <img alt="RxJS tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/rxjs.png"/>
#               <p>
#                RxJS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/react-native-tutorial">
#              <div class="homecontent">
#               <img alt="React Native tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/react-native.png"/>
#               <p>
#                React Native
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-design-pattern">
#              <div class="homecontent">
#               <img alt="Python Design Patterns" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python-design-patterns.png"/>
#               <p>
#                Python Design Patterns
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-pillow">
#              <div class="homecontent">
#               <img alt="Python Pillow tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python-pillow.png"/>
#               <p>
#                Python Pillow
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-turtle-programming">
#              <div class="homecontent">
#               <img alt="Python Turtle tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python-turtle.png"/>
#               <p>
#                Python Turtle
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/keras">
#              <div class="homecontent">
#               <img alt="Keras tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/keras.png"/>
#               <p>
#                Keras
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             Trending Technologies
#            </h2>
#            <div class="firsthomecontent">
#             <a href="https://www.javatpoint.com/artificial-intelligence-ai">
#              <div class="homecontent">
#               <img alt="Artificial Intelligence" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/artificial-intelligence.png"/>
#               <p>
#                Artificial Intelligence
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/aws-tutorial">
#              <div class="homecontent">
#               <img alt="AWS Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/amazon-web-services.png"/>
#               <p>
#                AWS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/selenium-tutorial">
#              <div class="homecontent">
#               <img alt="Selenium tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium.png"/>
#               <p>
#                Selenium
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/cloud-computing">
#              <div class="homecontent">
#               <img alt="Cloud Computing" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cloud-computing.png"/>
#               <p>
#                Cloud Computing
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/hadoop-tutorial">
#              <div class="homecontent">
#               <img alt="Hadoop tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/hadoop.png"/>
#               <p>
#                Hadoop
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/reactjs-tutorial">
#              <div class="homecontent">
#               <img alt="ReactJS Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/reactjs.png"/>
#               <p>
#                ReactJS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/data-science">
#              <div class="homecontent">
#               <img alt="Data Science Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-science.png"/>
#               <p>
#                Data Science
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/angular-7-tutorial">
#              <div class="homecontent">
#               <img alt="Angular 7 Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/angular7.png"/>
#               <p>
#                Angular 7
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/blockchain-tutorial">
#              <div class="homecontent">
#               <img alt="Blockchain Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/blockchain.png"/>
#               <p>
#                Blockchain
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/git">
#              <div class="homecontent">
#               <img alt="Git Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/git.png"/>
#               <p>
#                Git
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/machine-learning">
#              <div class="homecontent">
#               <img alt="Machine Learning Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/machine-learning.png"/>
#               <p>
#                Machine Learning
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/devops">
#              <div class="homecontent">
#               <img alt="DevOps Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/devops.png"/>
#               <p>
#                DevOps
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             Preparation
#            </h2>
#            <div class="firsthomecontent">
#             <a href="https://www.javatpoint.com/aptitude/quantitative">
#              <div class="homecontent">
#               <img alt="Aptitude" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/aptitude.png"/>
#               <p>
#                Aptitude
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/reasoning">
#              <div class="homecontent">
#               <img alt="Logical Reasoning" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/reasoning.png"/>
#               <p>
#                Reasoning
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/verbal-ability">
#              <div class="homecontent">
#               <img alt="Verbal Ability" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/verbal-ability.png"/>
#               <p>
#                Verbal Ability
#               </p>
#              </div>
#             </a>
#             <a href="interview-questions-and-answers">
#              <div class="homecontent">
#               <img alt="Interview Questions" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/interview-questions.png"/>
#               <p>
#                Interview Questions
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/company-interview-questions-and-recruitment-process">
#              <div class="homecontent">
#               <img alt="Company Interview Questions" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/company-questions.png"/>
#               <p>
#                Company Questions
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             B.Tech / MCA
#            </h2>
#            <div class="firsthomecontent">
#             <a href="https://www.javatpoint.com/dbms-tutorial">
#              <div class="homecontent">
#               <img alt="DBMS tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/dbms.png"/>
#               <p>
#                DBMS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/data-structure-tutorial">
#              <div class="homecontent">
#               <img alt="Data Structures tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-structures.png"/>
#               <p>
#                Data Structures
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/daa-tutorial">
#              <div class="homecontent">
#               <img alt="DAA tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/daa.png"/>
#               <p>
#                DAA
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/operating-system">
#              <div class="homecontent">
#               <img alt="Operating System" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/operating-system.png"/>
#               <p>
#                Operating System
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/computer-network-tutorial">
#              <div class="homecontent">
#               <img alt="Computer Network tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/computer-network.png"/>
#               <p>
#                Computer Network
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/compiler-tutorial">
#              <div class="homecontent">
#               <img alt="Compiler Design tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/compiler-design.png"/>
#               <p>
#                Compiler Design
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/computer-organization-and-architecture-tutorial">
#              <div class="homecontent">
#               <img alt="Computer Organization and Architecture" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/computer-organization.png"/>
#               <p>
#                Computer Organization
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/discrete-mathematics-tutorial">
#              <div class="homecontent">
#               <img alt="Discrete Mathematics Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/discrete-mathematics.png"/>
#               <p>
#                Discrete Mathematics
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/ethical-hacking">
#              <div class="homecontent">
#               <img alt="Ethical Hacking Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/ethical-hacking.png"/>
#               <p>
#                Ethical Hacking
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/computer-graphics-tutorial">
#              <div class="homecontent">
#               <img alt="Computer Graphics Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/computer-graphics.png"/>
#               <p>
#                Computer Graphics
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/software-engineering">
#              <div class="homecontent">
#               <img alt="Software Engineering" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/software-engineering.png"/>
#               <p>
#                Software Engineering
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/html-tutorial">
#              <div class="homecontent">
#               <img alt="html tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/web-technology.png"/>
#               <p>
#                Web Technology
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/cyber-security-tutorial">
#              <div class="homecontent">
#               <img alt="Cyber Security tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cyber-security.png"/>
#               <p>
#                Cyber Security
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/automata-tutorial">
#              <div class="homecontent">
#               <img alt="Automata Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/automata.png"/>
#               <p>
#                Automata
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/c-programming-language-tutorial">
#              <div class="homecontent">
#               <img alt="C Language tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/c-programming.png"/>
#               <p>
#                C Programming
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/cpp-tutorial">
#              <div class="homecontent">
#               <img alt="C++ tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cpp.png"/>
#               <p>
#                C++
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/java-tutorial">
#              <div class="homecontent">
#               <img alt="Java tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/java.png"/>
#               <p>
#                Java
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/net-framework">
#              <div class="homecontent">
#               <img alt=".Net Framework tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/dot-net.png"/>
#               <p>
#                .Net
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-tutorial">
#              <div class="homecontent">
#               <img alt="Python tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python.png"/>
#               <p>
#                Python
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/programs-list">
#              <div class="homecontent">
#               <img alt="List of Programs" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/programs.png"/>
#               <p>
#                Programs
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/control-system-tutorial">
#              <div class="homecontent">
#               <img alt="Control Systems tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/control-system.png"/>
#               <p>
#                Control System
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/data-mining">
#              <div class="homecontent">
#               <img alt="Data Mining Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-mining.png"/>
#               <p>
#                Data Mining
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/data-warehouse">
#              <div class="homecontent">
#               <img alt="Data Warehouse Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-warehouse.png"/>
#               <p>
#                Data Warehouse
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             Cloud Technologies
#            </h2>
#            <div class="firsthomecontent">
#             <a href="cloud-computing">
#              <div class="homecontent">
#               <img alt="Cloud tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cloud-computing.png"/>
#               <p>
#                Cloud Computing
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/aws-tutorial">
#              <div class="homecontent">
#               <img alt="AWS Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/amazon-web-services.png"/>
#               <p>
#                AWS
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/microsoft-azure">
#              <div class="homecontent">
#               <img alt="Microsoft Azure Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/azure.png"/>
#               <p>
#                Azure
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/salesforce">
#              <div class="homecontent">
#               <img alt="Salesforce Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/salesforce.png"/>
#               <p>
#                Salesforce
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/google-cloud-platform">
#              <div class="homecontent">
#               <img alt="Google Cloud Platform Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/google-cloud-platform.png"/>
#               <p>
#                Google Cloud
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             Testing Tutorials
#            </h2>
#            <div class="firsthomecontent">
#             <a href="https://www.javatpoint.com/software-testing-tutorial">
#              <div class="homecontent">
#               <img alt="Software Testing Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/software-testing.png"/>
#               <p>
#                Software Testing
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/selenium-tutorial">
#              <div class="homecontent">
#               <img alt="Selenium tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium.png"/>
#               <p>
#                Selenium
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/agile">
#              <div class="homecontent">
#               <img alt="Agile Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/agile.png"/>
#               <p>
#                Agile
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/jira-tutorial">
#              <div class="homecontent">
#               <img alt="JIRA Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jira.png"/>
#               <p>
#                JIRA
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/bugzilla">
#              <div class="homecontent">
#               <img alt="Bugzilla Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/bugzilla.png"/>
#               <p>
#                Bugzilla
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/etl-testing">
#              <div class="homecontent">
#               <img alt="ETL Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/etl.png"/>
#               <p>
#                ETL
#               </p>
#              </div>
#             </a>
#             <a href="jmeter-tutorial">
#              <div class="homecontent">
#               <img alt="JMeter tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jmeter.png"/>
#               <p>
#                JMeter
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/quality-assurance">
#              <div class="homecontent">
#               <img alt="quality assurance Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/quality-assurance.png"/>
#               <p>
#                QA
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/testng-tutorial">
#              <div class="homecontent">
#               <img alt="TestNG Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/testng.png"/>
#               <p>
#                TestNG
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/automation-anywhere">
#              <div class="homecontent">
#               <img alt="Automation Anywhere Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/automation-anywhere.png"/>
#               <p>
#                Automation Anywhere
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/uipath">
#              <div class="homecontent">
#               <img alt="UiPath Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/uipath.png"/>
#               <p>
#                UiPath
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/selenium-python">
#              <div class="homecontent">
#               <img alt="Selenium Python" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium-python.png"/>
#               <p>
#                Selenium Python
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/postman">
#              <div class="homecontent">
#               <img alt="Postman Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/postman.png"/>
#               <p>
#                Postman
#               </p>
#              </div>
#             </a>
#             <a href="junit-tutorial">
#              <div class="homecontent">
#               <img alt="JUnit tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/junit.png"/>
#               <p>
#                Junit
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/soapui">
#              <div class="homecontent">
#               <img alt="SoapUI tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/soapui.png"/>
#               <p>
#                SoapUI
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/rpa">
#              <div class="homecontent">
#               <img alt="RPA tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/rpa.png"/>
#               <p>
#                RPA
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/manual-testing">
#              <div class="homecontent">
#               <img alt="manual testing tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/manual-testing.png"/>
#               <p>
#                Manual Testing
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/cucumber-testing">
#              <div class="homecontent">
#               <img alt="cucumber tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cucumber.png"/>
#               <p>
#                Cucumber
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/appium">
#              <div class="homecontent">
#               <img alt="Appium tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/appium.png"/>
#               <p>
#                Appium
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             Python Tutorials
#            </h2>
#            <div class="firsthomecontent">
#             <a href="python-tutorial">
#              <div class="homecontent">
#               <img alt="Python tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python.png"/>
#               <p>
#                Python
#               </p>
#              </div>
#             </a>
#             <a href="django-tutorial">
#              <div class="homecontent">
#               <img alt="django tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/django.png"/>
#               <p>
#                Django
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/flask-tutorial">
#              <div class="homecontent">
#               <img alt="Flask Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/flask.png"/>
#               <p>
#                Flask
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/numpy-tutorial">
#              <div class="homecontent">
#               <img alt="Numpy Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/numpy.png"/>
#               <p>
#                NumPy
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-tkinter">
#              <div class="homecontent">
#               <img alt="Python Tkinter Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/tkinter.png"/>
#               <p>
#                Tkinter
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/pytorch">
#              <div class="homecontent">
#               <img alt="Pytorch Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/pytorch.png"/>
#               <p>
#                Pytorch
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/pygame">
#              <div class="homecontent">
#               <img alt="Pygame Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/pygame.png"/>
#               <p>
#                Pygame
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-scipy">
#              <div class="homecontent">
#               <img alt="Python Scipy Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/scipy.png"/>
#               <p>
#                Scipy
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-pandas">
#              <div class="homecontent">
#               <img alt="Pandas Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/pandas.png"/>
#               <p>
#                Pandas
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/opencv">
#              <div class="homecontent">
#               <img alt="OpenCV Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/opencv.png"/>
#               <p>
#                OpenCV
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/matplotlib">
#              <div class="homecontent">
#               <img alt="Matplotlib Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/matplotlib.png"/>
#               <p>
#                Matplotlib
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/python-openpyxl">
#              <div class="homecontent">
#               <img alt="Openpyxl Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/openpyxl.png"/>
#               <p>
#                Openpyxl
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/selenium-python">
#              <div class="homecontent">
#               <img alt="Selenium Python" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium-python.png"/>
#               <p>
#                Selenium Python
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/kivy">
#              <div class="homecontent">
#               <img alt="Kivy Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/kivy.png"/>
#               <p>
#                Kivy
#               </p>
#              </div>
#             </a>
#             <a href="https://www.javatpoint.com/jupyter-notebook">
#              <div class="homecontent">
#               <img alt="Jupyter Notebook Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jupyter.png"/>
#               <p>
#                Jupyter
#               </p>
#              </div>
#             </a>
#            </div>
#           </fieldset>
#           <hr class="hrhomebox"/>
#           <fieldset class="gra1">
#            <h2 class="h3">
#             Java Technology
#            </h2>
#            <div class="firsthomecontent">
#             <a href="java-tutorial">
#              <div class="homecontent">
#               <img alt="Core Java tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/core-java.png"/>
#               <p>
#                Java
#               </p>
#              </div>
#             </a>
#             <a href="servlet-tutorial">
#              <div class="homecontent">
#               <img alt="Java Servlet tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/servlet.png"/>
#               <p>
#                Servlet
#               </p>
#              </div>
#             </a>
#             <a href="jsp-tutorial">
#              <div class="homecontent">
#               <img alt="Java JSP tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jsp.png"/>
#               <p>
#                JSP
#               </p>
#              </div>
#             </a>
#             <a href="spring-boot-tutorial">
#              <div class="homecontent">
#               <img alt="Spring Boot tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spring-boot.png"/>
#               <p>
#                Spring Boot
#               </p>
#              </div>
#             </a>
#             <a href="spring-tutorial">
#              <div class="homecontent">
#               <img alt="Spring framework tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spring.png"/>
#               <p>
#                Spring Framework
#               </p>
#              </div>
#             </a>
#             <a href="hibernate-tutorial">
#              <div class="homecontent">
#               <img alt="Hibernate tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/hibernate.png"/>
#               <p>
#                Hibernate
#               </p>
#              </div>
#             </a>
#             <a href="design-patterns-in-java">
#              <div class="homecontent">
#               <img alt="Java Design Pattern tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/design-pattern.png"/>
#               <p>
#                Design Patterns
#               </p>
#              </div>
#             </a>
#             <a href="java-web-services-tutorial">
#              <div class="homecontent">
# ...
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-color-and-colour">
#         8th Apr - Difference Between Color and Colour
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-copyright-and-patent">
#         8th Apr - Difference Between Copyright and Patent
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-dispose-and-finalize-in-c-sharp">
#         8th Apr - Difference between Dispose and Finalize in C#
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-horizontal-and-vertical">
#         8th Apr - Difference Between Horizontal and Vertical
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-hotels-and-restaurants">
#         8th Apr - Difference Between Hotels and Restaurants
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-immigration-and-emigration">
#         8th Apr - Difference Between Immigration and Emigration
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-m31-and-m31s">
#         8th Apr - Difference Between M31 And M31s
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-memorandum-of-association-and-article-of-association">
#         8th Apr - Difference Between Memorandum Of Association And Article Of Association
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-oral-and-written-communication">
#         8th Apr - Difference Between Oral and Written Communication
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-primary-and-secondary-memory">
#         8th Apr - Difference between Primary and Secondary Memory
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-resistance-and-resistivity">
#         8th Apr - Difference between Resistance and Resistivity
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-shares-and-debenture">
#         8th Apr - Difference Between Shares and Debenture
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-village-and-city">
#         8th Apr - Difference Between Village and City
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-input-devices-and-output-devices">
#         8th Apr - Differences Between Input Devices and Output Devices
#        </a>
#       </li>
#       <li>
#        <a href="what-is-the-difference-between-encryption-and-hashing">
#         8th Apr - What is the difference between Encryption and Hashing
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-hazards-and-disasters">
#         8th Apr - Difference between Hazards and Disasters
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-hiv-and-aids">
#         8th Apr - Difference between HIV and AIDS
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-simile-and-metaphor">
#         8th Apr - Difference between Simile and Metaphor
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-internal-and-external-fertilization">
#         8th Apr - Difference Between Internal and External Fertilization
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-viruses-and-viroids">
#         8th Apr - Difference Between Viruses and Viroids
#        </a>
#       </li>
#       <li>
#        <a href="square-definition">
#         8th Apr - Square Definition
#        </a>
#       </li>
#       <li>
#        <a href="sterilization-definition">
#         8th Apr - Sterilization Definition
#        </a>
#       </li>
#       <li>
#        <a href="tourism-definition">
#         8th Apr - Tourism Definition
#        </a>
#       </li>
#       <li>
#        <a href="transpiration-definition">
#         8th Apr - Transpiration Definition
#        </a>
#       </li>
#       <li>
#        <a href="tuberculosis-definition">
#         8th Apr - Tuberculosis Definition
#        </a>
#       </li>
#       <li>
#        <a href="weather-definition">
#         8th Apr - Weather Definition
#        </a>
#       </li>
#       <li>
#        <a href="yoga-definition">
#         8th Apr - Yoga Definition
#        </a>
#       </li>
#       <li>
#        <a href="infertility-definition">
#         8th Apr - Infertility Definition
#        </a>
#       </li>
#       <li>
#        <a href="equilibrium-definition">
#         8th Apr - Equilibrium Definition
#        </a>
#       </li>
#       <li>
#        <a href="simple-harmonic-motion-definition">
#         8th Apr - Simple Harmonic Motion Definition
#        </a>
#       </li>
#       <li>
#        <a href="abstract-noun-definition">
#         8th Apr - Abstract Noun Definition
#        </a>
#       </li>
#       <li>
#        <a href="allele-definition">
#         8th Apr - Allele Definition
#        </a>
#       </li>
#       <li>
#        <a href="biochemistry-definition">
#         8th Apr - Biochemistry Definition
#        </a>
#       </li>
#       <li>
#        <a href="cytoplasm-definition">
#         8th Apr - Cytoplasm Definition
#        </a>
#       </li>
#       <li>
#        <a href="transportation-definition">
#         8th Apr - Transportation Definition
#        </a>
#       </li>
#       <li>
#        <a href="definition-of-growth-and-development">
#         8th Apr - Definition of Growth and Development
#        </a>
#       </li>
#       <li>
#        <a href="latent-heat-definition">
#         8th Apr - Latent Heat Definition
#        </a>
#       </li>
#       <li>
#        <a href="midwife-definition">
#         8th Apr - Midwife Definition
#        </a>
#       </li>
#       <li>
#        <a href="natural-disaster-definition">
#         8th Apr - Natural Disaster Definition
#        </a>
#       </li>
#       <li>
#        <a href="operating-system-definition">
#         8th Apr - Operating System Definition
#        </a>
#       </li>
#       <li>
#        <a href="prime-number-definition">
#         8th Apr - Prime Number Definition
#        </a>
#       </li>
#       <li>
#        <a href="quality-assurance-definition">
#         8th Apr - Quality Assurance Definition
#        </a>
#       </li>
#       <li>
#        <a href="water-definition">
#         8th Apr - Water Definition
#        </a>
#       </li>
#       <li>
#        <a href="web-browser-definition">
#         8th Apr - Web Browser Definition
#        </a>
#       </li>
#       <li>
#        <a href="weight-definition">
#         8th Apr - Weight Definition
#        </a>
#       </li>
#       <li>
#        <a href="solar-system-definition">
#         8th Apr - Solar System Definition
#        </a>
#       </li>
#       <li>
#        <a href="tourist-places-in-krishnagiri">
#         5th Apr - Tourist Places in Krishnagiri
#        </a>
#       </li>
#       <li>
#        <a href="tourist-places-in-kumarakom">
#         5th Apr - Tourist Places in Kumarakom
#        </a>
#       </li>
#       <li>
#        <a href="tourist-places-in-afghanistan">
#         5th Apr - Tourist Places in Afghanistan
#        </a>
#       </li>
#       <li>
#        <a href="tourist-places-in-namakkal">
#         5th Apr - Tourist Places in Namakkal
#        </a>
#       </li>
#       <li>
#        <a href="tourist-places-in-chidambaram">
#         5th Apr - Tourist Places in Chidambaram
#        </a>
#       </li>
#      </ol>
#      <ins class="adPushupAds" data-ac="..." data-adpcontrol="am3c1" data-siteid="37780" data-ver="2">
#      </ins>
#      <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#      </script>
#      <script data-cfasync="false" type="text/javascript">
#       (function (w, d) { for (var i = 0, j = d.getElementsByTagName("ins"), k = j[i]; i < j.length; k = j[++i]){ if(k.className == "adPushupAds" && k.getAttribute("data-push") != "1") { ((w.adpushup = w.adpushup || {}).control = (w.adpushup.control || [])).push(k); k.setAttribute("data-push", "1");} } })(window, document);
#      </script>
#      <br/>
#      <br/>
#     </div>
#     <div class="right1024" style="float:left;margin-left:10px;margin-top:10px;">
#      <ins class="adPushupAds" data-ac="..." data-adpcontrol="am3c1" data-siteid="37780" data-ver="2">
#      </ins>
#      <script data-cfasync="false" type="text/javascript">
#       (function (w, d) { for (var i = 0, j = d.getElementsByTagName("ins"), k = j[i]; i < j.length; k = j[++i]){ if(k.className == "adPushupAds" && k.getAttribute("data-push") != "1") { ((w.adpushup = w.adpushup || {}).control = (w.adpushup.control || [])).push(k); k.setAttribute("data-push", "1");} } })(window, document);
#      </script>
#     </div>
#     <div id="footer" style="clear:both;width:100%;">
#      <div style="width:100%;margin-top:10px;color:white;background-image: linear-gradient(145deg,#52a2fc,#480fcc);line-height:28px;">
#       <h2 style="padding:60px 0px 0px 20px">
#        Javatpoint Services
#       </h2>
#       <p style="padding:0px 20px 0px 20px">
#        JavaTpoint offers too many high quality services. Mail us on
#        <a class="__cf_email__" data-cfemail="afc7ddefc5ced9cedbdfc0c6c1db81ccc0c2" href="/cdn-cgi/l/email-protection">
#         [email protected]
#        </a>
#        , to get more information about given services.
#       </p>
#       <ul class="points">
#        <li>
#         Website Designing
#        </li>
#        <li>
#         Website Development
#        </li>
#        <li>
#         Java Development
#        </li>
#        <li>
#         PHP Development
#        </li>
#        <li>
#         WordPress
#        </li>
#        <li>
#         Graphic Designing
#        </li>
#        <li>
#         Logo
#        </li>
#        <li>
#         Digital Marketing
#        </li>
#        <li>
#         On Page and Off Page SEO
#        </li>
#        <li>
#         PPC
#        </li>
#        <li>
#         Content Development
#        </li>
#        <li>
#         Corporate Training
#        </li>
#        <li>
#         Classroom and Online Training
#        </li>
#        <li>
#         Data Entry
#        </li>
#       </ul>
#       <p style="padding-bottom:60px">
#       </p>
#      </div>
#      <div style="width:100%;margin-top:-20px;color:white;background-image: linear-gradient(145deg,#dc8140,#b16b15);line-height:28px;">
#       <h2 style="padding:60px 0px 0px 20px">
#        Training For College Campus
#       </h2>
#       <p style="padding:0px 20px 60px 20px">
#        JavaTpoint offers college campus training on Core Java, Advance Java, .Net, Android, Hadoop, PHP, Web Technology and Python. Please mail your requirement at
#        <a class="__cf_email__" data-cfemail="3d554f7d575c4b5c494d52545349135e525013" href="/cdn-cgi/l/email-protection">
#         [email protected]
#        </a>
#        <br/>
#        Duration: 1 week to 2 week
#        <br/>
#       </p>
#      </div>
#      <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#      </script>
#      <script>
#       var _gaq=_gaq || []; _gaq.push(['_setAccount', 'UA-24880427-1']); _gaq.push(['_trackPageview']); (function(){var ga=document.createElement('script'); ga.type='text/javascript'; ga.async=true; ga.src=('https:'==document.location.protocol ? 'https://ssl' : 'https://www') + '.google-analytics.com/ga.js'; var s=document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);})();
#      </script>
#      <div style="margin-top:5px;text-align:center">
#       <sup style="font:16px arial;">
#        Like/Subscribe us for latest updates or newsletter
#       </sup>
#       <a href="https://feeds.feedburner.com/javatpointsonoo" rel="nofollow noopener" target="_blank">
#        <img alt="RSS Feed" src="https://static.javatpoint.com/images/social/rss1.png"/>
#       </a>
#       <a href="https://feedburner.google.com/fb/a/mailverify?uri=javatpointsonoo" rel="nofollow noopener" target="_blank">
#        <img alt="Subscribe to Get Email Alerts" src="https://static.javatpoint.com/images/social/mail1.png"/>
#       </a>
#       <a href="https://www.facebook.com/javatpoint" rel="nofollow noopener" target="_blank">
#        <img alt="Facebook Page" src="https://static.javatpoint.com/images/social/facebook1.jpg"/>
#       </a>
#       <a href="https://twitter.com/pagejavatpoint" rel="nofollow" target="_blank noopener">
#        <img alt="Twitter Page" src="https://static.javatpoint.com/images/social/twitter1.png"/>
#       </a>
#       <a href="https://www.youtube.com/channel/UCUnYvQVCrJoFWZhKK3O2xLg" rel="nofollow noopener" target="_blank">
#        <img alt="YouTube" src="https://static.javatpoint.com/images/youtube32.png"/>
#       </a>
#       <a href="https://javatpoint.blogspot.com" rel="nofollow noopener" target="_blank">
#        <img alt="Blog Page" src="https://static.javatpoint.com/images/social/blog.png"/>
#       </a>
#      </div>
#      <footer class="footer1">
#       <div class="column4">
#        <h3>
#         Learn Tutorials
#        </h3>
#        <a href="https://www.javatpoint.com/java-tutorial">
#         Learn Java
#        </a>
#        <a href="https://www.javatpoint.com/data-structure-tutorial">
#         Learn Data Structures
#        </a>
#        <a href="https://www.javatpoint.com/c-programming-language-tutorial">
#         Learn C Programming
#        </a>
#        <a href="https://www.javatpoint.com/cpp-tutorial">
#         Learn C++ Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/c-sharp-tutorial">
#         Learn C# Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/php-tutorial">
#         Learn PHP Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/html-tutorial">
#         Learn HTML Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/javascript-tutorial">
#         Learn JavaScript Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/jquery-tutorial">
#         Learn jQuery Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/spring-tutorial">
#         Learn Spring Tutorial
#        </a>
#       </div>
#       <div class="column4">
#        <h3>
#         Our Websites
#        </h3>
#        <a href="https://www.javatpoint.com">
#         Javatpoint.com
#        </a>
#        <a href="https://www.hindi100.com" rel="dofollow noopener" target="_blank">
#         Hindi100.com
#        </a>
#        <a href="https://www.lyricsia.com" rel="dofollow noopener" target="_blank">
#         Lyricsia.com
#        </a>
#        <a href="https://www.quoteperson.com" rel="nofollow noopener" target="_blank">
#         Quoteperson.com
#        </a>
#        <a href="https://www.jobandplacement.com" rel="nofollow noopener" target="_blank">
#         Jobandplacement.com
#        </a>
#       </div>
#       <div class="column4">
#        <h3>
#         Our Services
#        </h3>
#        <p>
#         Website Development
#        </p>
#        <p>
#         Android Development
#        </p>
#        <p>
#         Website Designing
#        </p>
#        <p>
#         Digital Marketing
#        </p>
#        <p>
#         Summer Training
#        </p>
#        <p>
#         Industrial Training
#        </p>
#        <p>
#         College Campus Training
#        </p>
#       </div>
#       <div class="column4">
#        <h3>
#         Contact
#        </h3>
#        <p>
#         Address: G-13, 2nd Floor, Sec-3
#        </p>
#        <p>
#         Noida, UP, 201301, India
#        </p>
#        <p>
#         Contact No: 0120-4256464, 9990449935
#        </p>
#        <a href="https://www.javatpoint.com/contact-us">
#         Contact Us
#        </a>
#        <a href="https://www.javatpoint.com/subscribe.jsp">
#         Subscribe Us
#        </a>
#        <a href="https://www.javatpoint.com/privacy-policy">
#         Privacy Policy
#        </a>
#        <a href="https://www.javatpoint.com/sitemap.xml">
#         Sitemap
#        </a>
#        <br/>
#        <a href="https://www.javatpoint.com/sonoo-jaiswal">
#         About Me
#        </a>
#       </div>
#      </footer>
#      <footer class="footer2">
#       <p>
#        © Copyright 2011-2021 www.javatpoint.com. All rights reserved. Developed by JavaTpoint.
#       </p>
#      </footer>
#      <div id="bot-root">
#      </div>
#      <script>
#       (function() {
#  var e = document.createElement('script');
#  e.src = 'https://app.pushbrothers.com/js/notification-bot.js?cnfg=a3cc04a1-8471-450e-b01e-c9d752b16eb0';
#  document.getElementById('bot-root').appendChild(e);}());
#      </script>
#     </div>
#    </div>
#   </div>
#   <script src="https://static.javatpoint.com/js/shcoreandbrush.js">
#   </script>
#   <script>
#    dp.SyntaxHighlighter.HighlightAll('code');
#   </script>
#   <script async="" src="https://static.javatpoint.com/lazysizes.min.js">
#   </script>
#  </body>
# </html>

# %%
print(soup.title)
# Out:
# <title>Tutorials List - Javatpoint</title>

# %%
print(soup.title.text)
# Out:
# Tutorials List - Javatpoint

# %%
for link in soup.find_all("a"):  
  print("Inner Text is: {}".format(link.text))  
  print("Title is: {}".format(link.get("title")))  
  print("href is: {}".format(link.get("href")))
# Out:
# Inner Text is:
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is:
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is:  Home
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is:  Python
# Title is: None
# href is: python-tutorial
# Inner Text is:  Java
# Title is: None
# href is: java-tutorial
# Inner Text is:  JavaScript
# Title is: None
# href is: javascript-tutorial
# Inner Text is:  HTML
# Title is: None
# href is: html-tutorial
# Inner Text is:  SQL
# Title is: None
# href is: sql-tutorial
# Inner Text is:  PHP
# Title is: None
# href is: php-tutorial
# Inner Text is:  C#
# Title is: None
# href is: c-sharp-tutorial
# Inner Text is:  C++
# Title is: None
# href is: cpp-tutorial
# Inner Text is:  DS
# Title is: None
# href is: data-structure-tutorial
# Inner Text is:  Aptitude
# Title is: None
# href is: https://www.javatpoint.com/aptitude/quantitative
# Inner Text is:  Reasoning
# Title is: None
# href is: reasoning
# Inner Text is:  Selenium
# Title is: None
# href is: selenium-tutorial
# Inner Text is:  DBMS
# Title is: None
# href is: dbms-tutorial
# Inner Text is:  C
# Title is: None
# href is: c-programming-language-tutorial
# Inner Text is:  Android
# Title is: None
# href is: android-tutorial
# Inner Text is:  Interview Q
# Title is: None
# href is: interview-questions-and-answers
# Inner Text is:  Join Now
# Title is: None
# href is: https://bit.ly/2FOeX6S
# Inner Text is:
# Title is: None
# href is: https://training.javatpoint.com/
# Inner Text is:
# Title is: None
# href is: https://training.javatpoint.com/
# Inner Text is:
#
# Splunk
#
#
# Title is: None
# href is: https://www.javatpoint.com/splunk
# Inner Text is:
#
# SPSS
#
#
# Title is: None
# href is: https://www.javatpoint.com/spss
# Inner Text is:
#
# Swagger
#
#
# Title is: None
# href is: https://www.javatpoint.com/swagger
# Inner Text is:
#
# Transact-SQL
#
#
# Title is: None
# href is: https://www.javatpoint.com/t-sql
# Inner Text is:
#
# Tumblr
#
#
# Title is: None
# href is: https://www.javatpoint.com/tumblr
# Inner Text is:
#
# ReactJS
#
#
# Title is: None
# href is: https://www.javatpoint.com/reactjs-tutorial
# Inner Text is:
#
# Regex
#
#
# Title is: None
# href is: https://www.javatpoint.com/regex
# Inner Text is:
#
# Reinforcement Learning
#
#
# Title is: None
# href is: https://www.javatpoint.com/reinforcement-learning
# Inner Text is:
#
# R Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/r-tutorial
# Inner Text is:
#
# RxJS
#
#
# Title is: None
# href is: https://www.javatpoint.com/rxjs
# Inner Text is:
#
# React Native
#
#
# Title is: None
# href is: https://www.javatpoint.com/react-native-tutorial
# Inner Text is:
#
# Python Design Patterns
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-design-pattern
# Inner Text is:
#
# Python Pillow
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-pillow
# Inner Text is:
#
# Python Turtle
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-turtle-programming
# Inner Text is:
#
# Keras
#
#
# Title is: None
# href is: https://www.javatpoint.com/keras
# Inner Text is:
#
# Artificial Intelligence
#
#
# Title is: None
# href is: https://www.javatpoint.com/artificial-intelligence-ai
# Inner Text is:
#
# AWS
#
#
# Title is: None
# href is: https://www.javatpoint.com/aws-tutorial
# Inner Text is:
#
# Selenium
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-tutorial
# Inner Text is:
#
# Cloud Computing
#
#
# Title is: None
# href is: https://www.javatpoint.com/cloud-computing
# Inner Text is:
#
# Hadoop
#
#
# Title is: None
# href is: https://www.javatpoint.com/hadoop-tutorial
# Inner Text is:
#
# ReactJS
#
#
# Title is: None
# href is: https://www.javatpoint.com/reactjs-tutorial
# Inner Text is:
#
# Data Science
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-science
# Inner Text is:
#
# Angular 7
#
#
# Title is: None
# href is: https://www.javatpoint.com/angular-7-tutorial
# Inner Text is:
#
# Blockchain
#
#
# Title is: None
# href is: https://www.javatpoint.com/blockchain-tutorial
# Inner Text is:
#
# Git
#
#
# Title is: None
# href is: https://www.javatpoint.com/git
# Inner Text is:
#
# Machine Learning
#
#
# Title is: None
# href is: https://www.javatpoint.com/machine-learning
# Inner Text is:
#
# DevOps
#
#
# Title is: None
# href is: https://www.javatpoint.com/devops
# Inner Text is:
#
# Aptitude
#
#
# Title is: None
# href is: https://www.javatpoint.com/aptitude/quantitative
# Inner Text is:
#
# Reasoning
#
#
# Title is: None
# href is: https://www.javatpoint.com/reasoning
# Inner Text is:
#
# Verbal Ability
#
#
# Title is: None
# href is: https://www.javatpoint.com/verbal-ability
# Inner Text is:
#
# Interview Questions
#
#
# Title is: None
# href is: interview-questions-and-answers
# Inner Text is:
#
# Company Questions
#
#
# Title is: None
# href is: https://www.javatpoint.com/company-interview-questions-and-recruitment-process
# Inner Text is:
#
# DBMS
#
#
# Title is: None
# href is: https://www.javatpoint.com/dbms-tutorial
# Inner Text is:
#
# Data Structures
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-structure-tutorial
# Inner Text is:
#
# DAA
#
#
# Title is: None
# href is: https://www.javatpoint.com/daa-tutorial
# Inner Text is:
#
# Operating System
#
#
# Title is: None
# href is: https://www.javatpoint.com/operating-system
# Inner Text is:
#
# Computer Network
#
#
# Title is: None
# href is: https://www.javatpoint.com/computer-network-tutorial
# Inner Text is:
#
# Compiler Design
#
#
# Title is: None
# href is: https://www.javatpoint.com/compiler-tutorial
# Inner Text is:
#
# Computer Organization
#
#
# Title is: None
# href is: https://www.javatpoint.com/computer-organization-and-architecture-tutorial
# Inner Text is:
#
# Discrete Mathematics
#
#
# Title is: None
# href is: https://www.javatpoint.com/discrete-mathematics-tutorial
# Inner Text is:
#
# Ethical Hacking
#
#
# Title is: None
# href is: https://www.javatpoint.com/ethical-hacking
# Inner Text is:
#
# Computer Graphics
#
#
# Title is: None
# href is: https://www.javatpoint.com/computer-graphics-tutorial
# Inner Text is:
#
# Software Engineering
#
#
# Title is: None
# href is: https://www.javatpoint.com/software-engineering
# Inner Text is:
#
# Web Technology
#
#
# Title is: None
# href is: https://www.javatpoint.com/html-tutorial
# Inner Text is:
#
# Cyber Security
#
#
# Title is: None
# href is: https://www.javatpoint.com/cyber-security-tutorial
# Inner Text is:
#
# Automata
#
#
# Title is: None
# href is: https://www.javatpoint.com/automata-tutorial
# Inner Text is:
#
# C Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/c-programming-language-tutorial
# Inner Text is:
#
# C++
#
#
# Title is: None
# href is: https://www.javatpoint.com/cpp-tutorial
# Inner Text is:
#
# Java
#
#
# Title is: None
# href is: https://www.javatpoint.com/java-tutorial
# Inner Text is:
#
# .Net
#
#
# Title is: None
# href is: https://www.javatpoint.com/net-framework
# Inner Text is:
#
# Python
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-tutorial
# Inner Text is:
#
# Programs
#
#
# Title is: None
# href is: https://www.javatpoint.com/programs-list
# Inner Text is:
#
# Control System
#
#
# Title is: None
# href is: https://www.javatpoint.com/control-system-tutorial
# Inner Text is:
#
# Data Mining
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-mining
# Inner Text is:
#
# Data Warehouse
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-warehouse
# Inner Text is:
#
# Cloud Computing
#
#
# Title is: None
# href is: cloud-computing
# Inner Text is:
#
# AWS
#
#
# Title is: None
# href is: https://www.javatpoint.com/aws-tutorial
# Inner Text is:
#
# Azure
#
#
# Title is: None
# href is: https://www.javatpoint.com/microsoft-azure
# Inner Text is:
#
# Salesforce
#
#
# Title is: None
# href is: https://www.javatpoint.com/salesforce
# Inner Text is:
#
# Google Cloud
#
#
# Title is: None
# href is: https://www.javatpoint.com/google-cloud-platform
# Inner Text is:
#
# Software Testing
#
#
# Title is: None
# href is: https://www.javatpoint.com/software-testing-tutorial
# Inner Text is:
#
# Selenium
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-tutorial
# Inner Text is:
#
# Agile
#
#
# Title is: None
# href is: https://www.javatpoint.com/agile
# Inner Text is:
#
# JIRA
#
#
# Title is: None
# href is: https://www.javatpoint.com/jira-tutorial
# Inner Text is:
#
# Bugzilla
#
#
# Title is: None
# href is: https://www.javatpoint.com/bugzilla
# Inner Text is:
#
# ETL
#
#
# Title is: None
# href is: https://www.javatpoint.com/etl-testing
# Inner Text is:
#
# JMeter
#
#
# Title is: None
# href is: jmeter-tutorial
# Inner Text is:
#
# QA
#
#
# Title is: None
# href is: https://www.javatpoint.com/quality-assurance
# Inner Text is:
#
# TestNG
#
#
# Title is: None
# href is: https://www.javatpoint.com/testng-tutorial
# Inner Text is:
#
# Automation Anywhere
#
#
# Title is: None
# href is: https://www.javatpoint.com/automation-anywhere
# Inner Text is:
#
# UiPath
#
#
# Title is: None
# href is: https://www.javatpoint.com/uipath
# Inner Text is:
#
# Selenium Python
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-python
# Inner Text is:
#
# Postman
#
#
# Title is: None
# href is: https://www.javatpoint.com/postman
# Inner Text is:
#
# Junit
#
#
# Title is: None
# href is: junit-tutorial
# Inner Text is:
#
# SoapUI
#
#
# Title is: None
# href is: https://www.javatpoint.com/soapui
# Inner Text is:
#
# RPA
#
#
# Title is: None
# href is: https://www.javatpoint.com/rpa
# Inner Text is:
#
# Manual Testing
#
#
# Title is: None
# href is: https://www.javatpoint.com/manual-testing
# Inner Text is:
#
# Cucumber
#
#
# Title is: None
# href is: https://www.javatpoint.com/cucumber-testing
# Inner Text is:
#
# Appium
#
#
# Title is: None
# href is: https://www.javatpoint.com/appium
# Inner Text is:
#
# Python
#
#
# Title is: None
# href is: python-tutorial
# Inner Text is:
#
# Django
#
#
# Title is: None
# href is: django-tutorial
# Inner Text is:
#
# Flask
#
#
# Title is: None
# href is: https://www.javatpoint.com/flask-tutorial
# Inner Text is:
#
# NumPy
#
#
# Title is: None
# href is: https://www.javatpoint.com/numpy-tutorial
# Inner Text is:
#
# Tkinter
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-tkinter
# Inner Text is:
#
# Pytorch
#
#
# Title is: None
# href is: https://www.javatpoint.com/pytorch
# Inner Text is:
#
# Pygame
#
#
# Title is: None
# href is: https://www.javatpoint.com/pygame
# Inner Text is:
#
# Scipy
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-scipy
# Inner Text is:
#
# Pandas
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-pandas
# Inner Text is:
#
# OpenCV
#
#
# Title is: None
# href is: https://www.javatpoint.com/opencv
# Inner Text is:
#
# Matplotlib
#
#
# Title is: None
# href is: https://www.javatpoint.com/matplotlib
# Inner Text is:
#
# Openpyxl
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-openpyxl
# Inner Text is:
#
# Selenium Python
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-python
# Inner Text is:
#
# Kivy
#
#
# Title is: None
# href is: https://www.javatpoint.com/kivy
# Inner Text is:
#
# Jupyter
#
#
# Title is: None
# href is: https://www.javatpoint.com/jupyter-notebook
# Inner Text is:
#
# Java
#
#
# Title is: None
# href is: java-tutorial
# Inner Text is:
#
# Servlet
#
#
# Title is: None
# href is: servlet-tutorial
# Inner Text is:
#
# JSP
#
#
# Title is: None
# href is: jsp-tutorial
# Inner Text is:
#
# Spring Boot
#
#
# Title is: None
# href is: spring-boot-tutorial
# Inner Text is:
#
# Spring Framework
#
#
# Title is: None
# href is: spring-tutorial
# Inner Text is:
#
# Hibernate
#
#
# Title is: None
# href is: hibernate-tutorial
# Inner Text is:
#
# Design Patterns
#
#
# Title is: None
# href is: design-patterns-in-java
# Inner Text is:
#
# Java Web Services
#
#
# Title is: None
# href is: java-web-services-tutorial
# Inner Text is:
#
# Struts
#
#
# Title is: None
# href is: struts-2-tutorial
# Inner Text is:
#
# RESTful Web Services
#
#
# Title is: None
# href is: https://www.javatpoint.com/restful-web-services-tutorial
# Inner Text is:
#
# Microservices
#
#
# Title is: None
# href is: https://www.javatpoint.com/microservices
# Inner Text is:
#
# Spring Cloud
#
#
# Title is: None
# href is: https://www.javatpoint.com/spring-cloud
# Inner Text is:
#
# Jenkins
#
#
# Title is: None
# href is: https://www.javatpoint.com/jenkins
# Inner Text is:
#
# Java Swing
#
#
# Title is: None
# href is: java-swing
# Inner Text is:
#
# JavaFX
#
#
# Title is: None
# href is: javafx-tutorial
# Inner Text is:
#
# Maven
#
#
# Title is: None
# href is: maven-tutorial
# Inner Text is:
#
# Apache POI
#
#
# Title is: None
# href is: apache-poi-tutorial
# Inner Text is:
#
# JSF
#
#
# Title is: None
# href is: jsf-tutorial
# Inner Text is:
#
# EJB
#
#
# Title is: None
# href is: ejb-tutorial
# Inner Text is:
#
# JSTL
#
#
# Title is: None
# href is: jstl
# Inner Text is:
#
# Primefaces
#
#
# Title is: None
# href is: primefaces-tutorial
# Inner Text is:
#
# JDB
#
#
# Title is: None
# href is: jdb-tutorial
# Inner Text is:
#
# Apache Ant
#
#
# Title is: None
# href is: apache-ant-tutorial
# Inner Text is:
#
# JPA
#
#
# Title is: None
# href is: jpa-tutorial
# Inner Text is:
#
# Java Mail
#
#
# Title is: None
# href is: java-mail-api-tutorial
# Inner Text is:
#
# Jsoup
#
#
# Title is: None
# href is: jsoup-tutorial
# Inner Text is:
#
# JAXB
#
#
# Title is: None
# href is: jaxb-tutorial
# Inner Text is:
#
# Java I/O
#
#
# Title is: None
# href is: java-io
# Inner Text is:
#
# Java AWT
#
#
# Title is: None
# href is: java-awt
# Inner Text is:
#
# Collections
#
#
# Title is: None
# href is: collections-in-java
# Inner Text is:
#
# Java Date
#
#
# Title is: None
# href is: java-date
# Inner Text is:
#
# RichFaces
#
#
# Title is: None
# href is: richfaces-tutorial
# Inner Text is:
#
# JFreeChart
#
#
# Title is: None
# href is: jfreechart-tutorial
# Inner Text is:
#
# Java 9
#
#
# Title is: None
# href is: java-9-features
# Inner Text is:
#
# Java 8
#
#
# Title is: None
# href is: java-8-features
# Inner Text is:
#
# JOGL
#
#
# Title is: None
# href is: jogl-tutorial
# Inner Text is:
#
# Tika
#
#
# Title is: None
# href is: tika-tutorial
# Inner Text is:
#
# jBPM
#
#
# Title is: None
# href is: jbpm-tutorial
# Inner Text is:
#
# PDFBox
#
#
# Title is: None
# href is: pdfbox-tutorial
# Inner Text is:
#
# Intellij Idea
#
#
# Title is: None
# href is: https://www.javatpoint.com/intellij-idea-tutorial
# Inner Text is:
#
# SQL
#
#
# Title is: None
# href is: sql-tutorial
# Inner Text is:
#
# PL/SQL
#
#
# Title is: None
# href is: pl-sql-tutorial
# Inner Text is:
#
# MySQL
#
#
# Title is: None
# href is: mysql-tutorial
# Inner Text is:
#
# MongoDB
#
#
# Title is: None
# href is: mongodb-tutorial
# Inner Text is:
#
# PostgreSQL
#
#
# Title is: None
# href is: postgresql-tutorial
# Inner Text is:
#
# SQL Server
#
#
# Title is: None
# href is: sql-server-tutorial
# Inner Text is:
#
# Oracle
#
#
# Title is: None
# href is: oracle-tutorial
# Inner Text is:
#
# Cassandra
#
#
# Title is: None
# href is: cassandra-tutorial
# Inner Text is:
#
# SQLite
#
#
# Title is: None
# href is: sqlite-tutorial
# Inner Text is:
#
# Neo4j
#
#
# Title is: None
# href is: neo4j-tutorial
# Inner Text is:
#
# CouchDB
#
#
# Title is: None
# href is: couchdb-tutorial
# Inner Text is:
#
# MariaDB
#
#
# Title is: None
# href is: mariadb-tutorial
# Inner Text is:
#
# DB2
#
#
# Title is: None
# href is: db2-tutorial
# Inner Text is:
#
# PouchDB
#
#
# Title is: None
# href is: pouchdb-tutorial
# Inner Text is:
#
# Redis
#
#
# Title is: None
# href is: redis-tutorial
# Inner Text is:
#
# HTML
#
#
# Title is: None
# href is: html-tutorial
# Inner Text is:
#
# CSS
#
#
# Title is: None
# href is: css-tutorial
# Inner Text is:
#
# JavaScript
#
#
# Title is: None
# href is: javascript-tutorial
# Inner Text is:
#
# jQuery
#
#
# Title is: None
# href is: jquery-tutorial
# Inner Text is:
#
# jQuery UI
#
#
# Title is: None
# href is: jquery-ui-tutorial
# Inner Text is:
#
# PHP
#
#
# Title is: None
# href is: php-tutorial
# Inner Text is:
#
# XML
#
#
# Title is: None
# href is: xml-tutorial
# Inner Text is:
#
# JSON
#
#
# Title is: None
# href is: json-tutorial
# Inner Text is:
#
# AJAX
#
#
# Title is: None
# href is: ajax-tutorial
# Inner Text is:
#
# Web Serv-
#
#
# Title is: None
# href is: web-services-tutorial
# Inner Text is:
#
# Bootstrap
#
#
# Title is: None
# href is: bootstrap-tutorial
# Inner Text is:
#
# AngularJS
#
#
# Title is: None
# href is: angularjs-tutorial
# Inner Text is:
#
# Node.js
#
#
# Title is: None
# href is: nodejs-tutorial
# Inner Text is:
#
# Express.js
#
#
# Title is: None
# href is: expressjs-tutorial
# Inner Text is:
#
# Backbone
#
#
# Title is: None
# href is: backbonejs-tutorial
# Inner Text is:
#
# Sass
#
#
# Title is: None
# href is: sass-tutorial
# Inner Text is:
#
# Less
#
#
# Title is: None
# href is: less-tutorial
# Inner Text is:
#
# XSLT
#
#
# Title is: None
# href is: xslt-tutorial
# Inner Text is:
#
# XPath
#
#
# Title is: None
# href is: xpath-tutorial
# Inner Text is:
#
# XQuery
#
#
# Title is: None
# href is: xquery-tutorial
# Inner Text is:
#
# XHTML
#
#
# Title is: None
# href is: xhtml-tutorial
# Inner Text is:
#
# Pure.CSS
#
#
# Title is: None
# href is: pure-css-tutorial
# Inner Text is:
#
# Materialize
#
#
# Title is: None
# href is: materialize-css-tutorial
# Inner Text is:
#
# Framework7
#
#
# Title is: None
# href is: framework7-tutorial
# Inner Text is:
#
# HTTP
#
#
# Title is: None
# href is: https://www.javatpoint.com/http-tutorial
# Inner Text is:
#
# DHTML
#
#
# Title is: None
# href is: https://www.javatpoint.com/dhtml
# Inner Text is:
#
# PHP
#
#
# Title is: None
# href is: php-tutorial
# Inner Text is:
#
# Laravel
#
#
# Title is: None
# href is: https://www.javatpoint.com/laravel
# Inner Text is:
#
# WordPress
#
#
# Title is: None
# href is: wordpress-tutorial
# Inner Text is:
#
# CodeIgniter
#
#
# Title is: None
# href is: codeigniter-tutorial
# Inner Text is:
#
# Magento 2
#
#
# Title is: None
# href is: https://www.javatpoint.com/magento-2
# Inner Text is:
#
# Joomla
#
#
# Title is: None
# href is: https://www.javatpoint.com/joomla
# Inner Text is:
#
# Phalcon
#
#
# Title is: None
# href is: phalcon-tutorial
# Inner Text is:
#
# YII
#
#
# Title is: None
# href is: yii-tutorial
# Inner Text is:
#
# Xampp
#
#
# Title is: None
# href is: https://www.javatpoint.com/xampp
# Inner Text is:
#
# Excel
#
#
# Title is: None
# href is: excel-tutorial
# Inner Text is:
#
# MS Word
#
#
# Title is: None
# href is: ms-word-tutorial
# Inner Text is:
#
# Powerpoint
#
#
# Title is: None
# href is: powerpoint-tutorial
# Inner Text is:
#
# OneNote
#
#
# Title is: None
# href is: https://www.javatpoint.com/onenote
# Inner Text is:
#
# VBA
#
#
# Title is: None
# href is: https://www.javatpoint.com/vba
# Inner Text is:
#
# Power BI
#
#
# Title is: None
# href is: https://www.javatpoint.com/power-bi
# Inner Text is:
#
# QlikView
#
#
# Title is: None
# href is: https://www.javatpoint.com/qlikview
# Inner Text is:
#
# Powershell
#
#
# Title is: None
# href is: https://www.javatpoint.com/powershell
# Inner Text is:
#
# Classroom
#
#
# Title is: None
# href is: https://www.javatpoint.com/google-classroom
# Inner Text is:
#
# Smartsheet
#
#
# Title is: None
# href is: https://www.javatpoint.com/smartsheet
# Inner Text is:
#
# .Net
#
#
# Title is: None
# href is: net-framework
# Inner Text is:
#
# C#
#
#
# Title is: None
# href is: c-sharp-tutorial
# Inner Text is:
#
# ASP.NET
#
#
# Title is: None
# href is: asp-net-tutorial
# Inner Text is:
#
# ADO.NET
#
#
# Title is: None
# href is: ado-net-tutorial
# Inner Text is:
#
# WPF
#
#
# Title is: None
# href is: wpf
# Inner Text is:
#
# SSRS
#
#
# Title is: None
# href is: https://www.javatpoint.com/ssrs
# Inner Text is:
#
# SSIS
#
#
# Title is: None
# href is: https://www.javatpoint.com/ssis
# Inner Text is:
#
# Web API
#
#
# Title is: None
# href is: https://www.javatpoint.com/web-api
# Inner Text is:
#
# LINQ
#
#
# Title is: None
# href is: https://www.javatpoint.com/linq
# Inner Text is:
#
# SharePoint
#
#
# Title is: None
# href is: https://www.javatpoint.com/sharepoint
# Inner Text is:
#
# F#
#
#
# Title is: None
# href is: f-sharp-tutorial
# Inner Text is:
#
# VB.NET
#
#
# Title is: None
# href is: vb-net
# Inner Text is:
#
# C
#
#
# Title is: None
# href is: c-programming-language-tutorial
# Inner Text is:
#
# C++
#
#
# Title is: None
# href is: cpp-tutorial
# Inner Text is:
#
# Android
#
#
# Title is: None
# href is: android-tutorial
# Inner Text is:
#
# Computer
#
#
# Title is: None
# href is: computer-fundamentals-tutorial
# Inner Text is:
#
# Linux
#
#
# Title is: None
# href is: linux-tutorial
# Inner Text is:
#
# vi editor
#
#
# Title is: None
# href is: vi-editor
# Inner Text is:
#
# Embedded
#
#
# Title is: None
# href is: embedded-system-tutorial
# Inner Text is:
#
# Robotics
#
#
# Title is: None
# href is: robotics-tutorial
# Inner Text is:
#
# SEO
#
#
# Title is: None
# href is: seo-tutorial
# Inner Text is:
#
# Shell Script
#
#
# Title is: None
# href is: shell-scripting-tutorial
# Inner Text is:
#
# MathML
#
#
# Title is: None
# href is: mathml-tutorial
# Inner Text is:
#
# Perl
#
#
# Title is: None
# href is: perl-tutorial
# Inner Text is:
#
# Scala
#
#
# Title is: None
# href is: scala-tutorial
# Inner Text is:
#
# Ruby
#
#
# Title is: None
# href is: ruby-tutorial
# Inner Text is:
#
# Rails
#
#
# Title is: None
# href is: ruby-on-rails-tutorial
# Inner Text is:
#
# Docker
#
#
# Title is: None
# href is: docker-tutorial
# Inner Text is:
#
# GWT
#
#
# Title is: None
# href is: gwt-tutorial
# Inner Text is:
#
# Go Lang
#
#
# Title is: None
# href is: go-tutorial
# Inner Text is:
#
# On Ubuntu
#
#
# Title is: None
# href is: software-installation-in-ubuntu
# Inner Text is:
#
# On Mac
#
#
# Title is: None
# href is: software-installation-on-mac
# Inner Text is:
#
# On CentOS
#
#
# Title is: None
# href is: software-installation-on-centos
# Inner Text is:
#
# SVG
#
#
# Title is: None
# href is: svg-tutorial
# Inner Text is:
#
# Polymer
#
#
# Title is: None
# href is: polymer-tutorial
# Inner Text is:
#
# Kotlin
#
#
# Title is: None
# href is: kotlin-tutorial
# Inner Text is:
#
# Rust
#
#
# Title is: None
# href is: https://www.javatpoint.com/rust-tutorial
# Inner Text is:
#
# Control System
#
#
# Title is: None
# href is: https://www.javatpoint.com/control-system-tutorial
# Inner Text is:
#
# TypeScript
#
#
# Title is: None
# href is: https://www.javatpoint.com/typescript-tutorial
# Inner Text is:
#
#  Pig
#
#
# Title is: None
# href is: https://www.javatpoint.com/pig
# Inner Text is:
#
# Swift
#
#
# Title is: None
# href is: https://www.javatpoint.com/swift-tutorial
# Inner Text is:
#
# Spark
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-spark-tutorial
# Inner Text is:
#
# DIP
#
#
# Title is: None
# href is: https://www.javatpoint.com/digital-image-processing-tutorial
# Inner Text is:
#
# Mobile Communication
#
#
# Title is: None
# href is: https://www.javatpoint.com/mobile-communication-tutorial
# Inner Text is:
#
# SAS
#
#
# Title is: None
# href is: https://www.javatpoint.com/sas-tutorial
# Inner Text is:
#
# Electrical Machines
#
#
# Title is: None
# href is: https://www.javatpoint.com/electrical-machines-tutorial
# Inner Text is:
#
# Hive
#
#
# Title is: None
# href is: https://www.javatpoint.com/hive
# Inner Text is:
#
# Tableau
#
#
# Title is: None
# href is: https://www.javatpoint.com/tableau
# Inner Text is:
#
# NGINX
#
#
# Title is: None
# href is: https://www.javatpoint.com/nginx-tutorial
# Inner Text is:
#
# Log4j
#
#
# Title is: None
# href is: https://www.javatpoint.com/log4j
# Inner Text is:
#
# Bash
#
#
# Title is: None
# href is: https://www.javatpoint.com/bash
# Inner Text is:
#
# R
#
#
# Title is: None
# href is: https://www.javatpoint.com/r-tutorial
# Inner Text is:
#
# Git
#
#
# Title is: None
# href is: https://www.javatpoint.com/git
# Inner Text is:
#
# Wireshark
#
#
# Title is: None
# href is: https://www.javatpoint.com/wireshark
# Inner Text is:
#
# Xamarin
#
#
# Title is: None
# href is: https://www.javatpoint.com/xamarin
# Inner Text is:
#
# Tensorflow
#
#
# Title is: None
# href is: https://www.javatpoint.com/tensorflow
# Inner Text is:
#
# VHDL
#
#
# Title is: None
# href is: https://www.javatpoint.com/vhdl
# Inner Text is:
#
# Ionic
#
#
# Title is: None
# href is: https://www.javatpoint.com/ionic
# Inner Text is:
#
# NLP
#
#
# Title is: None
# href is: https://www.javatpoint.com/nlp
# Inner Text is:
#
# Latex
#
#
# Title is: None
# href is: https://www.javatpoint.com/latex
# Inner Text is:
#
# Inkscape
#
#
# Title is: None
# href is: https://www.javatpoint.com/inkscape
# Inner Text is:
#
#  Matlab
#
#
# Title is: None
# href is: https://www.javatpoint.com/matlab
# Inner Text is:
#
# GitHub
#
#
# Title is: None
# href is: https://www.javatpoint.com/github
# Inner Text is:
#
# Unity
#
#
# Title is: None
# href is: https://www.javatpoint.com/unity
# Inner Text is:
#
# SVN
#
#
# Title is: None
# href is: https://www.javatpoint.com/svn
# Inner Text is:
#
# Reinforcement
#
#
# Title is: None
# href is: https://www.javatpoint.com/reinforcement-learning
# Inner Text is:
#
# Kafka
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-kafka
# Inner Text is:
#
# Kali Linux
#
#
# Title is: None
# href is: https://www.javatpoint.com/kali-linux
# Inner Text is:
#
# Talend
#
#
# Title is: None
# href is: https://www.javatpoint.com/talend
# Inner Text is:
#
# Mockito
#
#
# Title is: None
# href is: https://www.javatpoint.com/mockito
# Inner Text is:
#
# Ansible
#
#
# Title is: None
# href is: https://www.javatpoint.com/ansible
# Inner Text is:
#
# Firebase
#
#
# Title is: None
# href is: https://www.javatpoint.com/firebase
# Inner Text is:
#
#  Cobol
#
#
# Title is: None
# href is: https://www.javatpoint.com/cobol
# Inner Text is:
#
# ES6
#
#
# Title is: None
# href is: https://www.javatpoint.com/es6
# Inner Text is:
#
# Flutter
#
#
# Title is: None
# href is: https://www.javatpoint.com/flutter
# Inner Text is:
#
# Gradle
#
#
# Title is: None
# href is: https://www.javatpoint.com/gradle
# Inner Text is:
#
# UML
#
#
# Title is: None
# href is: https://www.javatpoint.com/uml
# Inner Text is:
#
# ANN
#
#
# Title is: None
# href is: https://www.javatpoint.com/artificial-neural-network
# Inner Text is:
#
# Tally
#
#
# Title is: None
# href is: https://www.javatpoint.com/tally
# Inner Text is:
#
# Godot
#
#
# Title is: None
# href is: https://www.javatpoint.com/godot
# Inner Text is:
#
# AutoCad
#
#
# Title is: None
# href is: https://www.javatpoint.com/autocad
# Inner Text is:
#
# Kubernetes
#
#
# Title is: None
# href is: https://www.javatpoint.com/kubernetes
# Inner Text is:
#
# Puppet
#
#
# Title is: None
# href is: https://www.javatpoint.com/puppet
# Inner Text is:
#
# Math
#
#
# Title is: None
# href is: https://www.javatpoint.com/math
# Inner Text is:
#
# GDB
#
#
# Title is: None
# href is: https://www.javatpoint.com/gdb
# Inner Text is:
#
# Fuzzy Logic
#
#
# Title is: None
# href is: https://www.javatpoint.com/fuzzy-logic
# Inner Text is:
#
# Proc*C
#
#
# Title is: None
# href is: https://www.javatpoint.com/proc
# Inner Text is:
#
# SMM
#
#
# Title is: None
# href is: https://www.javatpoint.com/social-media-marketing
# Inner Text is:
#
# Affiliate Marketing
#
#
# Title is: None
# href is: https://www.javatpoint.com/affiliate-marketing
# Inner Text is:
#
# Arduino
#
#
# Title is: None
# href is: https://www.javatpoint.com/arduino
# Inner Text is:
#
# Digital Electronics
#
#
# Title is: None
# href is: https://www.javatpoint.com/digital-electronics
# Inner Text is:
#
# Adwords
#
#
# Title is: None
# href is: https://www.javatpoint.com/google-adwords
# Inner Text is:
#
# Ext.js
#
#
# Title is: None
# href is: https://www.javatpoint.com/ext-js
# Inner Text is:
#
# GraphQL
#
#
# Title is: None
# href is: https://www.javatpoint.com/graphql
# Inner Text is:
#
# IoT
#
#
# Title is: None
# href is: https://www.javatpoint.com/iot-internet-of-things
# Inner Text is:
#
# Gmail
#
#
# Title is: None
# href is: https://www.javatpoint.com/gmail
# Inner Text is:
#
# Vue.js
#
#
# Title is: None
# href is: https://www.javatpoint.com/vue-js
# Inner Text is:
#
# Landing Page
#
#
# Title is: None
# href is: https://www.javatpoint.com/landing-pages
# Inner Text is:
#
# PLC
#
#
# Title is: None
# href is: https://www.javatpoint.com/plc
# Inner Text is:
#
# Illustrator
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-illustrator
# Inner Text is:
#
# Memcached
#
#
# Title is: None
# href is: https://www.javatpoint.com/memcached-tutorial
# Inner Text is:
#
# Solr
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-solr
# Inner Text is:
#
# Gimp
#
#
# Title is: None
# href is: https://www.javatpoint.com/gimp
# Inner Text is:
#
# Verilog
#
#
# Title is: None
# href is: https://www.javatpoint.com/verilog
# Inner Text is:
#
# Teradata
#
#
# Title is: None
# href is: https://www.javatpoint.com/teradata
# Inner Text is:
#
# PhoneGap
#
#
# Title is: None
# href is: https://www.javatpoint.com/phonegap
# Inner Text is:
#
# Bootstrap 4
#
#
# Title is: None
# href is: https://www.javatpoint.com/bootstrap-4
# Inner Text is:
#
# Chrome
#
#
# Title is: None
# href is: https://www.javatpoint.com/what-is-google-chrome
# Inner Text is:
#
# Dart
#
#
# Title is: None
# href is: https://www.javatpoint.com/dart-programming
# Inner Text is:
#
# Adobe After Effects
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-after-effect
# Inner Text is:
#
# Adobe Dreamweaver
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-dreamweaver
# Inner Text is:
#
# Adobe CorelDRAW
#
#
# Title is: None
# href is: https://www.javatpoint.com/coreldraw
# Inner Text is:
#
# Adobe Indesign
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-indesign
# Inner Text is:
#
# Audacity
#
#
# Title is: None
# href is: https://www.javatpoint.com/audacity
# Inner Text is:
#
# Blue Prism
#
#
# Title is: None
# href is: https://www.javatpoint.com/blue-prism
# Inner Text is:
#
# Python CGI Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-cgi-programming
# Inner Text is:
#
# Cordova
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-cordova
# Inner Text is:
#
# d3.js
#
#
# Title is: None
# href is: https://www.javatpoint.com/d3-js
# Inner Text is:
#
# Dialogflow
#
#
# Title is: None
# href is: https://www.javatpoint.com/dialogflow
# Inner Text is:
#
# Ionic
#
#
# Title is: None
# href is: https://www.javatpoint.com/ionic
# Inner Text is:
#
# ITIL
#
#
# Title is: None
# href is: https://www.javatpoint.com/itil
# Inner Text is:
#
# IOS with Swift
#
#
# Title is: None
# href is: https://www.javatpoint.com/ios-development-using-swift
# Inner Text is:
#
# Angular Material
#
#
# Title is: None
# href is: https://www.javatpoint.com/angular-material
# Inner Text is:
#
# Deep Learning
#
#
# Title is: None
# href is: https://www.javatpoint.com/deep-learning
# Inner Text is:
#
# Google Colab
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-programming-with-google-colab
# Inner Text is:
#
# Graph Theory
#
#
# Title is: None
# href is: https://www.javatpoint.com/graph-theory
# Inner Text is:
#
# Groovy
#
#
# Title is: None
# href is: https://www.javatpoint.com/groovy
# Inner Text is:
#
# Group Discussion
#
#
# Title is: None
# href is: https://www.javatpoint.com/group-discussion
# Inner Text is:
#
# Informatica
#
#
# Title is: None
# href is: https://www.javatpoint.com/informatica
# Inner Text is:
#
# Digital Marketing
#
#
# Title is: None
# href is: https://www.javatpoint.com/digital-marketing
# Inner Text is:
#
# Elasticsearch
#
#
# Title is: None
# href is: https://www.javatpoint.com/elasticsearch
# Inner Text is:
#
# Entity Framework
#
#
# Title is: None
# href is: https://www.javatpoint.com/entity-framework
# Inner Text is:
#
# Firewall
#
#
# Title is: None
# href is: https://www.javatpoint.com/firewall
# Inner Text is:
#
# Functional Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/functional-programming
# Inner Text is:
#
# Photoshop
#
#
# Title is: None
# href is: https://www.javatpoint.com/photoshop
# Inner Text is:
#
# Prolog
#
#
# Title is: None
# href is: https://www.javatpoint.com/prolog
# Inner Text is:
#
# PWA
#
#
# Title is: None
# href is: https://www.javatpoint.com/progressive-web-applications
# Inner Text is:
#
# Pyspark
#
#
# Title is: None
# href is: https://www.javatpoint.com/pyspark
# Inner Text is:
#
# Nagios
#
#
# Title is: None
# href is: https://www.javatpoint.com/nagios
# Inner Text is:
#
# Nifi
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-nifi
# Inner Text is:
#
# Online Marketing
#
#
# Title is: None
# href is: https://www.javatpoint.com/online-marketing
# Inner Text is:
#
# OpenStack
#
#
# Title is: None
# href is: https://www.javatpoint.com/openstack
# Inner Text is:
#
# PDF
#
#
# Title is: None
# href is: https://www.javatpoint.com/pdf
# Inner Text is:
#
# Kibana
#
#
# Title is: None
# href is: https://www.javatpoint.com/kibana
# Inner Text is:
#
# Mean Stack
#
#
# Title is: None
# href is: https://www.javatpoint.com/mean-stack-tutorial
# Inner Text is:
#
# Microprocessor
#
#
# Title is: None
# href is: https://www.javatpoint.com/microprocessor-tutorial
# Inner Text is:
#
# Mobile Computing
#
#
# Title is: None
# href is: https://www.javatpoint.com/mobile-computing
# Inner Text is:
#
# Mobile Testing
#
#
# Title is: None
# href is: https://www.javatpoint.com/mobile-application-testing
# Inner Text is:
#
# Interview Questions
#
#
# Title is: None
# href is: interview-questions-and-answers
# Inner Text is:
#
# Projects
#
#
# Title is: None
# href is: free-java-projects
# Inner Text is:
#
# Forum
#
#
# Title is: None
# href is: forum
# Inner Text is:
#
# Quiz
#
#
# Title is: None
# href is: examaccess
# Inner Text is:
#
# Java Compiler
#
#
# Title is: None
# href is: https://compiler.javatpoint.com/opr/online-java-compiler.jsp
# Inner Text is:
#
# Full Form
#
#
# Title is: None
# href is: full-form
# Inner Text is:
#
# Difference
#
#
# Title is: None
# href is: difference-between
# Inner Text is:
#
# Holidays
#
#
# Title is: None
# href is: holidays/holidays
# Inner Text is:
#
# Health
#
#
# Title is: None
# href is: how-to-lose-weight
# Inner Text is:
#
# HR
#
#
# Title is: None
# href is: hr-tutorial
# Inner Text is:
#
# Marketing
#
#
# Title is: None
# href is: marketing-tutorial
# Inner Text is:
#
# Quotes
#
#
# Title is: None
# href is: https://www.quoteperson.com
# Inner Text is:
#
# Holidays
#
#
# Title is: None
# href is: holidays/american-holidays
# Inner Text is:
#
# Pin Code
#
#
# Title is: None
# href is: india-pin-codes
# Inner Text is:
#
# IFSC Code
#
#
# Title is: None
# href is: ifsc-code
# Inner Text is: - About Me
# Title is: None
# href is: sonoo-jaiswal
# Inner Text is: 14-day Semrush Free Pro Trial for Javatpoint
# Title is: None
# href is: https://semrush.sjv.io/c/4124850/1648349/13053
# Inner Text is: [email protected]
# Title is: None
# href is: /cdn-cgi/l/email-protection
# Inner Text is: 3rd May - AVL Tree Program in C
# Title is: None
# href is: avl-tree-program-in-c
# Inner Text is: 3rd May - B Tree Applications
# Title is: None
# href is: b-tree-applications
# Inner Text is: 3rd May - B Tree Properties
# Title is: None
# href is: b-tree-properties
# Inner Text is: 3rd May - How to Search, Insert, and Delete in an Unsorted Array
# Title is: None
# href is: how-to-search-insert-and-delete-in-an-unsorted-array
# Inner Text is: 3rd May - Count Non-Leaf Nodes in a Binary Tree
# Title is: None
# href is: count-non-leaf-nodes-in-a-binary-tree
# Inner Text is: 3rd May - Get the Level of a Given Key in a Binary Tree
# Title is: None
# href is: get-the-level-of-a-given-key-in-a-binary-tree
# Inner Text is: 3rd May - Double Ended Priority Queue
# Title is: None
# href is: double-ended-priority-queue
# Inner Text is: 3rd May - Dirty Read in SQL in DBMS
# Title is: None
# href is: dirty-read-in-sql-in-dbms
# Inner Text is: 3rd May - ER Diagram for Student Management System
# Title is: None
# href is: er-diagram-for-student-management-system
# Inner Text is: 3rd May - ER Diagram for the Airline Reservation System
# Title is: None
# href is: er-diagram-for-the-airline-reservation-system
# Inner Text is: 3rd May - ER Diagram for the University Management System
# Title is: None
# href is: er-diagram-for-the-university-management-system
# Inner Text is: 3rd May - Functions of Distributed Database System in DBMS
# Title is: None
# href is: functions-of-distributed-database-system-in-dbms
# Inner Text is: 3rd May - Starvation in DBMS
# Title is: None
# href is: starvation-in-dbms
# Inner Text is: 3rd May - Implementation of Atomicity and Durability in DBMS
# Title is: None
# href is: implementation-of-atomicity-and-durability-in-dbms
# Inner Text is: 3rd May - Mesh Networks: A decentralized and Self-Organizing Approach to Networking
# Title is: None
# href is: mesh-networks
# Inner Text is: 3rd May - What is Autonomous System
# Title is: None
# href is: what-is-autonomous-system
# Inner Text is: 3rd May - What is MSS
# Title is: None
# href is: what-is-mss
# Inner Text is: 3rd May - Cyber security and Software security
# Title is: None
# href is: cyber-security-and-software-security
# Inner Text is: 3rd May - Information security and Network security
# Title is: None
# href is: information-security-and-network-security
# Inner Text is: 3rd May - Security Engineer and Security Architect
# Title is: None
# href is: security-engineer-and-security-architect
# Inner Text is: 3rd May - Protection Methods for Network Security
# Title is: None
# href is: protection-methods-for-network-security
# Inner Text is: 3rd May - Trusted Systems in Network Security
# Title is: None
# href is: trusted-systems-in-network-security
# Inner Text is: 3rd May - What are Authentication Tokens in Network security
# Title is: None
# href is: what-are-authentication-tokens-in-network-security
# Inner Text is: 3rd May - Cookies in Network Security
# Title is: None
# href is: cookies-in-network-security
# Inner Text is: 3rd May - Intruders in Network Security
# Title is: None
# href is: intruders-in-network-security
# Inner Text is: 3rd May - Network Security Toolkit (NST) in virtual box
# Title is: None
# href is: network-security-toolkit-in-virtual-box
# Inner Text is: 3rd May - Pivoting-Moving Inside a Network
# Title is: None
# href is: pivoting-moving-inside-a-network
# Inner Text is: 3rd May - Security Environment in Computer Networks
# Title is: None
# href is: security-environment-in-computer-networks
# Inner Text is: 3rd May - Voice Biometric technique in Network Security
# Title is: None
# href is: voice-biometric-technique-in-network-security
# Inner Text is: 2nd May - How long should a laptop battery last
# Title is: None
# href is: how-long-should-a-laptop-battery-last
# Inner Text is: 2nd May - What is Right-click
# Title is: None
# href is: what-is-right-click
# Inner Text is: 2nd May - What is PS/2
# Title is: None
# href is: what-is-ps-2
# Inner Text is: 2nd May - What is Raster File
# Title is: None
# href is: what-is-raster-file
# Inner Text is: 2nd May - What is the ntdll.dll file
# Title is: None
# href is: what-is-the-ntdll-dll-file
# Inner Text is: 2nd May - What is a Memory Slot
# Title is: None
# href is: what-is-a-memory-slot
# Inner Text is: 2nd May - What is a Tablet
# Title is: None
# href is: what-is-a-tablet
# Inner Text is: 2nd May - What is Back
# Title is: None
# href is: what-is-back
# Inner Text is: 2nd May - What is an opto mechanical mouse
# Title is: None
# href is: what-is-an-opto-mechanical-mouse
# Inner Text is: 2nd May - First 20 Elements
# Title is: None
# href is: first-20-elements
# Inner Text is: 2nd May - First Order Reaction
# Title is: None
# href is: first-order-reaction
# Inner Text is: 2nd May - Electronic Configuration of First 30 Elements
# Title is: None
# href is: electronic-configuration-of-first-30-elements
# Inner Text is: 2nd May - Periodicity of Valence or Oxidation State of Elements
# Title is: None
# href is: periodicity-of-valence-or-oxidation-state-of-elements
# Inner Text is: 2nd May - C Program For Printing Inverted Pyramid
# Title is: None
# href is: c-program-for-printing-inverted-pyramid
# Inner Text is: 2nd May - Control String in C Language
# Title is: None
# href is: control-string-in-c-language
# Inner Text is: 2nd May - How to Find Time Complexity of a Program in C
# Title is: None
# href is: how-to-find-time-complexity-of-a-program-in-c
# Inner Text is: 2nd May - Top C Projects in 2023
# Title is: None
# href is: top-c-projects-in-2023
# Inner Text is: 2nd May - Convert a Char Array into a Double in C
# Title is: None
# href is: convert-a-char-array-into-a-double-in-c
# Inner Text is: 2nd May - Conio.h in C
# Title is: None
# href is: conio-h-in-c
# Inner Text is: 2nd May - Decision-Making Statements in C
# Title is: None
# href is: decision-making-statements-in-c
# Inner Text is: 2nd May - What is Hashing in C
# Title is: None
# href is: what-is-hashing-in-c
# Inner Text is: 2nd May - Accounting Convention
# Title is: None
# href is: accounting-convention
# Inner Text is: 2nd May - Accounting Event
# Title is: None
# href is: accounting-event
# Inner Text is: 2nd May - Accounting Policies
# Title is: None
# href is: accounting-policies
# Inner Text is: 2nd May - Accounting Profit
# Title is: None
# href is: accounting-profit
# Inner Text is: 2nd May - Audit Cycle
# Title is: None
# href is: audit-cycle
# Inner Text is: 2nd May - Best Accounting Software for Small Business
# Title is: None
# href is: best-accounting-software-for-small-business
# Inner Text is: 2nd May - Blocked Account
# Title is: None
# href is: blocked-account
# Inner Text is: 2nd May - Cash Accounting
# Title is: None
# href is: cash-accounting
# Inner Text is: 2nd May - Financial Ratio Analysis: Definition, Types, Examples, and How to Use
# Title is: None
# href is: ratio-analysis
# Inner Text is: 2nd May - Financial Statements: List of Types and How to Read Them
# Title is: None
# href is: financial-statements
# Inner Text is: 2nd May - Introduction to Accounting Information Systems (AIS)
# Title is: None
# href is: accounting-information-systems
# Inner Text is: 2nd May - Law of Diminishing Marginal Utility
# Title is: None
# href is: law-of-diminishing-utility
# Inner Text is: 2nd May - Seller
# Title is: None
# href is: seller
# Inner Text is: 2nd May - New Account
# Title is: None
# href is: temporary-new-account
# Inner Text is: 2nd May - The 7 Best Accounting Books in 2023
# Title is: None
# href is: best-accounting-books
# Inner Text is: 2nd May - Translation Exposure
# Title is: None
# href is: translation-exposure
# Inner Text is: 2nd May - Understanding Liquidity and How to Measure It
# Title is: None
# href is: liquidity
# Inner Text is: 2nd May - Understanding the Cash Flow Statement
# Title is: None
# href is: what-is-a-cash-flow-statement
# Inner Text is: 2nd May - What Are Financial Statement Assertions
# Title is: None
# href is: what-are-financial-statement-assertions
# Inner Text is: 2nd May - What Is Accounting Fraud
# Title is: None
# href is: what-is-accounting-fraud
# Inner Text is: 2nd May - 3 Reasons Banks Can Freeze Your Account
# Title is: None
# href is: 3-reasons-banks-can-freeze-your-account
# Inner Text is: 2nd May - Accounting Method
# Title is: None
# href is: accounting-method
# Inner Text is: 2nd May - Accounting Postulate
# Title is: None
# href is: accounting-postulate
# Inner Text is: 2nd May - Accounting Practice
# Title is: None
# href is: accounting-practice
# Inner Text is: 2nd May - Accounting Ratio
# Title is: None
# href is: accounting-ratio
# Inner Text is: 2nd May - Accounting Records
# Title is: None
# href is: accounting-records
# Inner Text is: 2nd May - Accounts Receivable (AR): What It Is and How Businesses Use It, With Examples
# Title is: None
# href is: accounts-receivable
# Inner Text is: 2nd May - Financial Accounting Standards Board (FASB)
# Title is: None
# href is: fasb
# Inner Text is: 2nd May - The 8 Important Steps in the Accounting Cycle
# Title is: None
# href is: what-are-most-important-steps-accounting-cycle
# Inner Text is: 27th Apr - B.Sc. IT Full Form
# Title is: None
# href is: bsc-it-full-form
# Inner Text is: 27th Apr - BSTC Full Form
# Title is: None
# href is: bstc-full-form
# Inner Text is: 27th Apr - BSW Full Form
# Title is: None
# href is: bsw-full-form
# Inner Text is: 27th Apr - CKD Full Form
# Title is: None
# href is: ckd-full-form
# Inner Text is: 27th Apr - SDPO Full Form
# Title is: None
# href is: sdpo-full-form
# Inner Text is: 27th Apr - ULIP Full Form
# Title is: None
# href is: ulip-full-form
# Inner Text is: 27th Apr - CAPA Full Form
# Title is: None
# href is: capa-full-form
# Inner Text is: 27th Apr - CAS Full Form
# Title is: None
# href is: cas-full-form
# Inner Text is: 27th Apr - WBCS Full Form
# Title is: None
# href is: wbcs-full-form
# Inner Text is: 27th Apr - CBIC Full Form
# Title is: None
# href is: cbic-full-form
# Inner Text is: 27th Apr - CMM Full Form
# Title is: None
# href is: cmm-full-form
# Inner Text is: 27th Apr - COD Full Form
# Title is: None
# href is: cod-full-form
# Inner Text is: 27th Apr - BAMS Full Form in Medical
# Title is: None
# href is: bams-full-form-in-medical
# Inner Text is: 27th Apr - WIP Full Form
# Title is: None
# href is: wip-full-form
# Inner Text is: 27th Apr - AU Bank Full Form
# Title is: None
# href is: au-bank-full-form
# Inner Text is: 27th Apr - ACB Full Form
# Title is: None
# href is: acb-full-form
# Inner Text is: 27th Apr - Difference between preventDefault() and stopPropagation() methods
# Title is: None
# href is: difference-between-preventdefault-and-stoppropagation-methods
# Inner Text is: 27th Apr - JavaScript padStart() Method
# Title is: None
# href is: javascript-padstart-method
# Inner Text is: 27th Apr - Javascript promise chaining
# Title is: None
# href is: javascript-promise-chaining
# Inner Text is: 27th Apr - How to check two array values are equal in JavaScript
# Title is: None
# href is: how-to-check-two-array-values-are-equal-in-javascript
# Inner Text is: 27th Apr - How to remove a Key/Property from an object in JavaScript
# Title is: None
# href is: how-to-remove-a-key-property-from-an-object-in-javascript
# Inner Text is: 27th Apr - JavaScript Endswith() Function
# Title is: None
# href is: javascript-endswith-function
# Inner Text is: 27th Apr - How to draw a line using javascript
# Title is: None
# href is: how-to-draw-a-line-using-javascript
# Inner Text is: 27th Apr - JavaScript windows getComputedStyle() Method
# Title is: None
# href is: javascript-windows-getcomputedstyle-method
# Inner Text is: 27th Apr - Jagged Array in Java
# Title is: None
# href is: jagged-array-in-java
# Inner Text is: 27th Apr - CloneNotSupportedException in Java with Examples
# Title is: None
# href is: clonenotsupportedexception-in-java-with-examples
# Inner Text is: 27th Apr - Difference Between Function and Method in Java
# Title is: None
# href is: difference-between-function-and-method-in-java
# Inner Text is: 27th Apr - Immutable List in Java
# Title is: None
# href is: immutable-list-in-java
# Inner Text is: 27th Apr - Nesting Of Methods in Java
# Title is: None
# href is: nesting-of-methods-in-java
# Inner Text is: 27th Apr - How to Convert Date into Character Month and Year Java
# Title is: None
# href is: how-to-convert-date-into-character-month-and-year-java
# Inner Text is: 27th Apr - How to Mock Lambda Expression in Java
# Title is: None
# href is: how-to-mock-lambda-expression-in-java
# Inner Text is: 27th Apr - How to Return Value from Lambda Expression Java
# Title is: None
# href is: how-to-return-value-from-lambda-expression-java
# Inner Text is: 27th Apr - if Condition in Lambda Expression Java
# Title is: None
# href is: if-condition-in-lambda-expression-java
# Inner Text is: 27th Apr - Chained Exceptions in Java
# Title is: None
# href is: chained-exceptions-in-java
# Inner Text is: 27th Apr - Final static variable in Java
# Title is: None
# href is: final-static-variable-in-java
# Inner Text is: 27th Apr - Java File Watcher
# Title is: None
# href is: java-file-watcher
# Inner Text is: 27th Apr - Various Operations on HashSet in Java
# Title is: None
# href is: various-operations-on-hashset-in-java
# Inner Text is: 27th Apr - Word Ladder Problem in Java
# Title is: None
# href is: word-ladder-problem-in-java
# Inner Text is: 27th Apr - Various Operations on Queue in Java
# Title is: None
# href is: various-operations-on-queue-in-java
# Inner Text is: 27th Apr - Various Operations on Queue Using Linked List in Java
# Title is: None
# href is: various-operations-on-queue-using-linked-list-in-java
# Inner Text is: 27th Apr - Various Operations on Queue Using Stack in Java
# Title is: None
# href is: various-operations-on-queue-using-stack-in-java
# Inner Text is: 26th Apr - Best Android Games with Controller Support
# Title is: None
# href is: best-android-games-with-controller-support
# Inner Text is: 26th Apr - How to Turn Off or On Autocorrect on Android
# Title is: None
# href is: how-to-turn-off-or-on-autocorrect-on-android
# Inner Text is: 26th Apr - How to View Google Location History on Android
# Title is: None
# href is: how-to-view-google-location-history-on-android
# Inner Text is: 26th Apr - Ringtone Apps for Android and iPhone
# Title is: None
# href is: ringtone-apps-for-android-and-iphone
# Inner Text is: 26th Apr - Chatbot vs. Conversational AI
# Title is: None
# href is: chatbot-vs-conversational-ai
# Inner Text is: 26th Apr - Iterative Deepening A* Algorithm (IDA*)
# Title is: None
# href is: iterative-deepening-a-algorithm
# Inner Text is: 26th Apr - Iterative Deepening Search (IDS) or Iterative Deepening Depth First Search (IDDFS)
# Title is: None
# href is: iterative-deepening-search-or-iterative-deepening-depth-first-search
# Inner Text is: 25th Apr - Convert Camel Case String in Snake Case in C++
# Title is: None
# href is: convert-camel-case-string-in-snake-case-in-cpp
# Inner Text is: 25th Apr - C++ Program to Draw Histogram
# Title is: None
# href is: cpp-program-to-draw-histogram
# Inner Text is: 25th Apr - C++ DSA
# Title is: None
# href is: cpp-dsa
# Inner Text is: 25th Apr - C++ Flow Control
# Title is: None
# href is: cpp-flow-control
# Inner Text is: 25th Apr - C++ program to group anagrams in the given stream of strings
# Title is: None
# href is: cpp-program-to-group-anagrams-in-the-given-stream-of-strings
# Inner Text is: 25th Apr - cstdlib in C++
# Title is: None
# href is: cstdlib-in-cpp
# Inner Text is: 25th Apr - Everything You Need to Know About Conio.h Library Functions in C/C++
# Title is: None
# href is: everything-you-need-to-know-about-conio-h-library-functions-in-c-or-cpp
# Inner Text is: 25th Apr - Increment and Decrement Operators in C++
# Title is: None
# href is: increment-and-decrement-operators-in-cpp
# Inner Text is: 25th Apr - How to generate random number between 1 to 10 in C++
# Title is: None
# href is: how-to-generate-random-number-between-1-to-10-in-cpp
# Inner Text is: 25th Apr - How to Manipulate cout Object using C++ IOS Library
# Title is: None
# href is: how-to-manipulate-cout-object-using-cpp-ios-library
# Inner Text is: 25th Apr - Sliding Window Algorithm in C++
# Title is: None
# href is: sliding-window-algorithm-in-cpp
# Inner Text is: 25th Apr - What is Bottom-up Approach in C++
# Title is: None
# href is: what-is-bottom-up-approach-in-cpp
# Inner Text is: 25th Apr - What is Top-Down Approach in C++
# Title is: None
# href is: what-is-top-down-approach-in-cpp
# Inner Text is: 25th Apr - Bitmask in C++
# Title is: None
# href is: bitmask-in-cpp
# Inner Text is: 25th Apr - Ordered Map C++
# Title is: None
# href is: ordered-map-in-cpp
# Inner Text is: 25th Apr - Characteristics of Destructor in C++
# Title is: None
# href is: characteristics-of-destructor-in-cpp
# Inner Text is: 25th Apr - Factory Design Pattern C++
# Title is: None
# href is: factory-design-pattern-cpp
# Inner Text is: 25th Apr - REPL C++
# Title is: None
# href is: repl-cpp
# ...
# Title is: None
# href is: free-ms-office-certification-online
# Inner Text is: 15th Apr - Muv-Luv: Alternative Alternatives
# Title is: None
# href is: muv-luv-alternative-alternatives
# Inner Text is: 13th Apr - How to clone an object in JavaScript
# Title is: None
# href is: how-to-clone-an-object-in-javascript
# Inner Text is: 13th Apr - How to compare objects in JavaScript
# Title is: None
# href is: how-to-compare-objects-in-javascript
# Inner Text is: 13th Apr - How to truncate a string in JavaScript
# Title is: None
# href is: how-to-truncate-a-string-in-javascript
# Inner Text is: 13th Apr - JavaScript Nullish Coalescing Operator
# Title is: None
# href is: javascript-nullish-coalescing-operator
# Inner Text is: 13th Apr - The Promise.race() static method in JavaScript
# Title is: None
# href is: promise-race-static-method-in-javascript
# Inner Text is: 13th Apr - The nextElementSibling Property in javascript
# Title is: None
# href is: nextelementsibling-property-in-javascript
# Inner Text is: 13th Apr - JavaScript Promise.allSettled() Method
# Title is: None
# href is: javascript-promise-allsettled-method
# Inner Text is: 13th Apr - JavaScript Proxy
# Title is: None
# href is: javascript-proxy
# Inner Text is: 13th Apr - How to check empty string in JavaScript
# Title is: None
# href is: how-to-check-empty-string-in-javascript
# Inner Text is: 13th Apr - How to copy the text to clipboard in JavaScript
# Title is: None
# href is: how-to-copy-the-text-to-clipboard-in-javascript
# Inner Text is: 13th Apr - How to shuffle an array in JavaScript
# Title is: None
# href is: how-to-shuffle-an-array-in-javascript
# Inner Text is: 13th Apr - Javascript DOMContentLoaded event
# Title is: None
# href is: javascript-domcontentloaded-event
# Inner Text is: 13th Apr - Javascript promise.finally() method
# Title is: None
# href is: javascript-promise-finally-method
# Inner Text is: 13th Apr - JavaScript Promise.any() Method
# Title is: None
# href is: javascript-promise-any-method
# Inner Text is: 13th Apr - Object.key() in JavaScript
# Title is: None
# href is: object-key-in-javascript
# Inner Text is: 13th Apr - Shallow Copy and Deep Copy in JavaScript
# Title is: None
# href is: shallow-copy-and-deep-copy-in-javascript
# Inner Text is: 13th Apr - Radial Menu with JavaScript
# Title is: None
# href is: radial-menu-with-javascript
# Inner Text is: 13th Apr - Convert String to Boolean in JavaScript
# Title is: None
# href is: convert-string-to-boolean-in-javascript
# Inner Text is: 13th Apr - How to flatten an array in JavaScript
# Title is: None
# href is: how-to-flatten-an-array-in-javascript
# Inner Text is: 13th Apr - 1313 Angel Number Meaning
# Title is: None
# href is: 1313-angel-number-meaning
# Inner Text is: 13th Apr - What is 0.24 in Percent Form
# Title is: None
# href is: what-is-0-24-in-percent-form
# Inner Text is: 13th Apr - What is 003 as a Percentage
# Title is: None
# href is: what-is-003-as-a-percentage
# Inner Text is: 13th Apr - What is the Sum of all Numbers from 1 to 99
# Title is: None
# href is: what-is-the-sum-of-all-numbers-from-1-to-99
# Inner Text is: 13th Apr - Number Name 1 to 50 in English
# Title is: None
# href is: number-name-1-to-50-in-english
# Inner Text is: 13th Apr - Zero Vector (Null Vector)
# Title is: None
# href is: zero-vector-null-vector
# Inner Text is: 13th Apr - Area of Quarter Circle
# Title is: None
# href is: area-of-quarter-circle
# Inner Text is: 13th Apr - How to Calculate Cubic Meter Volume
# Title is: None
# href is: how-to-calculate-cubic-meter-volume
# Inner Text is: 13th Apr - Triangular Numbers
# Title is: None
# href is: triangular-numbers
# Inner Text is: 11th Apr - Calculator using Shunting yard algorithm in HTML using JavaScript
# Title is: None
# href is: calculator-using-shunting-yard-algorithm-in-html-using-javascript
# Inner Text is: 11th Apr - Different ways to build a calculator in HTML using JavaScript
# Title is: None
# href is: different-ways-to-build-a-calculator-in-html-using-javascript
# Inner Text is: 11th Apr - Publishing your Calculator website using Github pages (Beginner level)
# Title is: None
# href is: publishing-your-calculator-website-using-github-pages
# Inner Text is: 11th Apr - Move an image on button clicks in HTML using CSS and JavaScript
# Title is: None
# href is: move-an-image-on-button-clicks-in-html-using-css-and-javascript
# Inner Text is: 11th Apr - How to avoid thread deadlock in Java
# Title is: None
# href is: how-to-avoid-thread-deadlock-in-java
# Inner Text is: 11th Apr - Number of Squareful Arrays in Java
# Title is: None
# href is: number-of-squareful-arrays-in-java
# Inner Text is: 11th Apr - One-Time Password Generator Code In Java
# Title is: None
# href is: one-time-password-generator-code-in-java
# Inner Text is: 11th Apr - Real-Time Face Recognition In Java
# Title is: None
# href is: real-time-face-recognition-in-java
# Inner Text is: 11th Apr - Converting Integer Data Type to Byte Data Type Using Typecasting in Java
# Title is: None
# href is: converting-integer-data-type-to-byte-data-type-using-typecasting-in-java
# Inner Text is: 11th Apr - How to Generate File checksum Value
# Title is: None
# href is: how-to-generate-file-checksum-value
# Inner Text is: 11th Apr - Index Mapping (or Trivial Hashing) With Negatives allowed in Java
# Title is: None
# href is: index-mapping-or-trivial-hashing-with-negatives-allowed-in-java
# Inner Text is: 11th Apr - Shortest Path in a Binary Maze in Java
# Title is: None
# href is: shortest-path-in-a-binary-maze-in-java
# Inner Text is: 11th Apr - customized exception in Java
# Title is: None
# href is: customized-exception-in-java
# Inner Text is: 11th Apr - Difference between error and exception in Java
# Title is: None
# href is: difference-between-error-and-exception-in-java
# Inner Text is: 11th Apr - How to solve deprecated error in Java
# Title is: None
# href is: how-to-solve-deprecated-error-in-java
# Inner Text is: 9th Apr - C# Custom Attribute
# Title is: None
# href is: c-sharp-custom-attribute
# Inner Text is: 9th Apr - C# Game Development
# Title is: None
# href is: c-sharp-game-development
# Inner Text is: 9th Apr - C# Rename File
# Title is: None
# href is: c-sharp-rename-file
# Inner Text is: 9th Apr - C# Validate Email
# Title is: None
# href is: c-sharp-validate-email
# Inner Text is: 9th Apr - C# WebClient
# Title is: None
# href is: c-sharp-webclient
# Inner Text is: 9th Apr - C# XML Parser
# Title is: None
# href is: c-sharp-xml-parser
# Inner Text is: 9th Apr - Gender in English Grammar
# Title is: None
# href is: gender-in-english-grammar
# Inner Text is: 9th Apr - Number in English Grammar
# Title is: None
# href is: number-in-english-grammar
# Inner Text is: 9th Apr - Degree in English Grammar
# Title is: None
# href is: degree-in-english-grammar
# Inner Text is: 9th Apr - Linkers in English Grammar
# Title is: None
# href is: linkers-in-english-grammar
# Inner Text is: 9th Apr - Case In English Grammar
# Title is: None
# href is: case-in-english-grammar
# Inner Text is: 9th Apr - Punctuation in English Grammar
# Title is: None
# href is: punctuation-in-english-grammar
# Inner Text is: 9th Apr - English Grammar Rules
# Title is: None
# href is: english-grammar-rules
# Inner Text is: 8th Apr - Difference between Cyclic and Non-Cyclic Photophosphorylation
# Title is: None
# href is: difference-between-cyclic-and-non-cyclic-photophosphorylation
# Inner Text is: 8th Apr - Difference Between Algae and Fungi
# Title is: None
# href is: difference-between-algae-and-fungi
# Inner Text is: 8th Apr - Difference Between NBFC and Bank
# Title is: None
# href is: difference-between-nbfc-and-bank
# Inner Text is: 8th Apr - Difference Between Cleanser and Face Wash
# Title is: None
# href is: difference-between-cleanser-and-face-wash
# Inner Text is: 8th Apr - Difference Between Coat and Blazer
# Title is: None
# href is: difference-between-coat-and-blazer
# Inner Text is: 8th Apr - Difference Between Color and Colour
# Title is: None
# href is: difference-between-color-and-colour
# Inner Text is: 8th Apr - Difference Between Copyright and Patent
# Title is: None
# href is: difference-between-copyright-and-patent
# Inner Text is: 8th Apr - Difference between Dispose and Finalize in C#
# Title is: None
# href is: difference-between-dispose-and-finalize-in-c-sharp
# Inner Text is: 8th Apr - Difference Between Horizontal and Vertical
# Title is: None
# href is: difference-between-horizontal-and-vertical
# Inner Text is: 8th Apr - Difference Between Hotels and Restaurants
# Title is: None
# href is: difference-between-hotels-and-restaurants
# Inner Text is: 8th Apr - Difference Between Immigration and Emigration
# Title is: None
# href is: difference-between-immigration-and-emigration
# Inner Text is: 8th Apr - Difference Between M31 And M31s
# Title is: None
# href is: difference-between-m31-and-m31s
# Inner Text is: 8th Apr - Difference Between Memorandum Of Association And Article Of Association
# Title is: None
# href is: difference-between-memorandum-of-association-and-article-of-association
# Inner Text is: 8th Apr - Difference Between Oral and Written Communication
# Title is: None
# href is: difference-between-oral-and-written-communication
# Inner Text is: 8th Apr - Difference between Primary and Secondary Memory
# Title is: None
# href is: difference-between-primary-and-secondary-memory
# Inner Text is: 8th Apr - Difference between Resistance and Resistivity
# Title is: None
# href is: difference-between-resistance-and-resistivity
# Inner Text is: 8th Apr - Difference Between Shares and Debenture
# Title is: None
# href is: difference-between-shares-and-debenture
# Inner Text is: 8th Apr - Difference Between Village and City
# Title is: None
# href is: difference-between-village-and-city
# Inner Text is: 8th Apr - Differences Between Input Devices and Output Devices
# Title is: None
# href is: difference-between-input-devices-and-output-devices
# Inner Text is: 8th Apr - What is the difference between Encryption and Hashing
# Title is: None
# href is: what-is-the-difference-between-encryption-and-hashing
# Inner Text is: 8th Apr - Difference between Hazards and Disasters
# Title is: None
# href is: difference-between-hazards-and-disasters
# Inner Text is: 8th Apr - Difference between HIV and AIDS
# Title is: None
# href is: difference-between-hiv-and-aids
# Inner Text is: 8th Apr - Difference between Simile and Metaphor
# Title is: None
# href is: difference-between-simile-and-metaphor
# Inner Text is: 8th Apr - Difference Between Internal and External Fertilization
# Title is: None
# href is: difference-between-internal-and-external-fertilization
# Inner Text is: 8th Apr - Difference Between Viruses and Viroids
# Title is: None
# href is: difference-between-viruses-and-viroids
# Inner Text is: 8th Apr - Square Definition
# Title is: None
# href is: square-definition
# Inner Text is: 8th Apr - Sterilization Definition
# Title is: None
# href is: sterilization-definition
# Inner Text is: 8th Apr - Tourism Definition
# Title is: None
# href is: tourism-definition
# Inner Text is: 8th Apr - Transpiration Definition
# Title is: None
# href is: transpiration-definition
# Inner Text is: 8th Apr - Tuberculosis Definition
# Title is: None
# href is: tuberculosis-definition
# Inner Text is: 8th Apr - Weather Definition
# Title is: None
# href is: weather-definition
# Inner Text is: 8th Apr - Yoga Definition
# Title is: None
# href is: yoga-definition
# Inner Text is: 8th Apr - Infertility Definition
# Title is: None
# href is: infertility-definition
# Inner Text is: 8th Apr - Equilibrium Definition
# Title is: None
# href is: equilibrium-definition
# Inner Text is: 8th Apr - Simple Harmonic Motion Definition
# Title is: None
# href is: simple-harmonic-motion-definition
# Inner Text is: 8th Apr - Abstract Noun Definition
# Title is: None
# href is: abstract-noun-definition
# Inner Text is: 8th Apr - Allele Definition
# Title is: None
# href is: allele-definition
# Inner Text is: 8th Apr - Biochemistry Definition
# Title is: None
# href is: biochemistry-definition
# Inner Text is: 8th Apr - Cytoplasm Definition
# Title is: None
# href is: cytoplasm-definition
# Inner Text is: 8th Apr - Transportation Definition
# Title is: None
# href is: transportation-definition
# Inner Text is: 8th Apr - Definition of Growth and Development
# Title is: None
# href is: definition-of-growth-and-development
# Inner Text is: 8th Apr - Latent Heat Definition
# Title is: None
# href is: latent-heat-definition
# Inner Text is: 8th Apr - Midwife Definition
# Title is: None
# href is: midwife-definition
# Inner Text is: 8th Apr - Natural Disaster Definition
# Title is: None
# href is: natural-disaster-definition
# Inner Text is: 8th Apr - Operating System Definition
# Title is: None
# href is: operating-system-definition
# Inner Text is: 8th Apr - Prime Number Definition
# Title is: None
# href is: prime-number-definition
# Inner Text is: 8th Apr - Quality Assurance Definition
# Title is: None
# href is: quality-assurance-definition
# Inner Text is: 8th Apr - Water Definition
# Title is: None
# href is: water-definition
# Inner Text is: 8th Apr - Web Browser Definition
# Title is: None
# href is: web-browser-definition
# Inner Text is: 8th Apr - Weight Definition
# Title is: None
# href is: weight-definition
# Inner Text is: 8th Apr - Solar System Definition
# Title is: None
# href is: solar-system-definition
# Inner Text is: 5th Apr - Tourist Places in Krishnagiri
# Title is: None
# href is: tourist-places-in-krishnagiri
# Inner Text is: 5th Apr - Tourist Places in Kumarakom
# Title is: None
# href is: tourist-places-in-kumarakom
# Inner Text is: 5th Apr - Tourist Places in Afghanistan
# Title is: None
# href is: tourist-places-in-afghanistan
# Inner Text is: 5th Apr - Tourist Places in Namakkal
# Title is: None
# href is: tourist-places-in-namakkal
# Inner Text is: 5th Apr - Tourist Places in Chidambaram
# Title is: None
# href is: tourist-places-in-chidambaram
# Inner Text is: [email protected]
# Title is: None
# href is: /cdn-cgi/l/email-protection
# Inner Text is: [email protected]
# Title is: None
# href is: /cdn-cgi/l/email-protection
# Inner Text is:
# Title is: None
# href is: https://feeds.feedburner.com/javatpointsonoo
# Inner Text is:
# Title is: None
# href is: https://feedburner.google.com/fb/a/mailverify?uri=javatpointsonoo
# Inner Text is:
# Title is: None
# href is: https://www.facebook.com/javatpoint
# Inner Text is:
# Title is: None
# href is: https://twitter.com/pagejavatpoint
# Inner Text is:
# Title is: None
# href is: https://www.youtube.com/channel/UCUnYvQVCrJoFWZhKK3O2xLg
# Inner Text is:
# Title is: None
# href is: https://javatpoint.blogspot.com
# Inner Text is: Learn Java
# Title is: None
# href is: https://www.javatpoint.com/java-tutorial
# Inner Text is: Learn Data Structures
# Title is: None
# href is: https://www.javatpoint.com/data-structure-tutorial
# Inner Text is: Learn C Programming
# Title is: None
# href is: https://www.javatpoint.com/c-programming-language-tutorial
# Inner Text is: Learn C++ Tutorial
# Title is: None
# href is: https://www.javatpoint.com/cpp-tutorial
# Inner Text is: Learn C# Tutorial
# Title is: None
# href is: https://www.javatpoint.com/c-sharp-tutorial
# Inner Text is: Learn PHP Tutorial
# Title is: None
# href is: https://www.javatpoint.com/php-tutorial
# Inner Text is: Learn HTML Tutorial
# Title is: None
# href is: https://www.javatpoint.com/html-tutorial
# Inner Text is: Learn JavaScript Tutorial
# Title is: None
# href is: https://www.javatpoint.com/javascript-tutorial
# Inner Text is: Learn jQuery Tutorial
# Title is: None
# href is: https://www.javatpoint.com/jquery-tutorial
# Inner Text is: Learn Spring Tutorial
# Title is: None
# href is: https://www.javatpoint.com/spring-tutorial
# Inner Text is: Javatpoint.com
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is: Hindi100.com
# Title is: None
# href is: https://www.hindi100.com
# Inner Text is: Lyricsia.com
# Title is: None
# href is: https://www.lyricsia.com
# Inner Text is: Quoteperson.com
# Title is: None
# href is: https://www.quoteperson.com
# Inner Text is: Jobandplacement.com
# Title is: None
# href is: https://www.jobandplacement.com
# Inner Text is: Contact Us
# Title is: None
# href is: https://www.javatpoint.com/contact-us
# Inner Text is: Subscribe Us
# Title is: None
# href is: https://www.javatpoint.com/subscribe.jsp
# Inner Text is: Privacy Policy
# Title is: None
# href is: https://www.javatpoint.com/privacy-policy
# Inner Text is: Sitemap
# Title is: None
# href is: https://www.javatpoint.com/sitemap.xml
# Inner Text is: About Me
# Title is: None
# href is: https://www.javatpoint.com/sonoo-jaiswal
